# %% [markdown]
# # Wrangling OpenStreetMap Data with SQL

# %% [markdown]
# # Map Area
#
# San Diego, California,USA
#
# https://www.openstreetmap.org/relation/253832
#
# https://mapzen.com/data/metro-extracts/metro/san-diego_california/

# %% [markdown]
# # Downloading OSM XML file and taking a sample out of it

# %%
# OSM XML file and taking a sample out of it

import xml.etree.ElementTree as ET
import pprint
from collections import defaultdict
import re
import csv
import codecs
import cerberus
#import schema
import sqlite3


OSM_FILE = "san-diego_california.osm"
SAMPLE_FILE = "sample.osm"
k = 40

# %% [markdown]
# # Getting the elements with tags - nodes and way

# %%
# Getting the elements with tags - nodes and way

def get_element(filename, tags=('node', 'way', 'relation')):
    context = iter(ET.iterparse(filename, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()

# %% [markdown]
# # Taking sample from OSM_FILE

# %%
# Taking sample from OSM_FILE


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

# Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')
    output.close()

# %% [markdown]
# # Auditing :

# %% [markdown]
# # Counting the element tags in the file

# %%
# Counting the element tags in the file

def count_tags(filename):
    tree=ET.iterparse(filename)
    tags={}
    for event,elem in tree:
        if elem.tag not in tags.keys():
            tags[elem.tag]=1
        else:
            tags[elem.tag] = tags[elem.tag]+1
    return tags    
    
with open(OSM_FILE,'rb') as f:
    tags=count_tags(OSM_FILE)
    pprint.pprint(tags)
f.close()
# Out:
# {'bounds': 1,
#  'member': 13043,
#  'nd': 800964,
#  'node': 1017755,
#  'osm': 1,
#  'relation': 691,
#  'tag': 2628756,
#  'way': 88531}

# %% [markdown]
# # Finding out formatting scheme of K attribute in tags

# %%
# Finding out formatting scheme of K attribute in tags

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        if lower.search(element.attrib['k']):
            keys['lower'] += 1
        elif lower_colon.search(element.attrib['k']):
            keys['lower_colon'] += 1
        elif problemchars.search(element.attrib['k']):
            keys['problemchars'] = keys['problemchars'] + 1
        else:    
            keys['other'] += 1  
#            print element.attrib['k']
#            print element.attrib['v']
    return keys


def process_keys_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

with open(OSM_FILE,'rb') as f:
    keys = process_keys_map(OSM_FILE)
    pprint.pprint(keys)
f.close()
# Out:
# {'lower': 637400, 'lower_colon': 1953885, 'other': 37466, 'problemchars': 5}

# %% [markdown]
# # Finding unique k (tag attrib['k']) and count

# %%
# Finding unique k (tag attrib['k']) and count

def unique_keys(filename):
    distinct_keys=[]
    count=1

    EL=get_element(filename, tags=('node', 'way', 'relation'))
    for element in EL:
        if element.tag=='node' or element.tag=='way':
            for tag in element.iter('tag'):
                if tag.attrib['k'] not in distinct_keys:
                    distinct_keys.append(tag.attrib['k'])
                    count+=1
    distinct_keys.sort()
    print "Total number of unique keys (tag attrib['k'])is {}".format(count)
    
#    return distinct_keys
      
    pprint.pprint(distinct_keys)
    
                
unique_keys(SAMPLE_FILE)  # Using Sample file as input to audit the addr:street key
# Out:
# Total number of unique keys (tag attrib['k'])is 202
# ['FIXME',
#  'NHS',
#  'Tiger:MTFCC',
#  'access',
#  'addr:city',
#  'addr:country',
#  'addr:housenumber',
#  'addr:postcode',
#  'addr:state',
#  'addr:street',
#  'addr:unit',
#  'aeroway',
#  'amenity',
#  'area',
#  'barrier',
#  'beacon',
#  'beacon:colour',
#  'bench',
#  'bicycle',
#  'bridge',
#  'building',
#  'building:levels',
#  'building_type',
#  'cables',
#  'change:lanes',
#  'change:lanes:backward',
#  'change:lanes:forward',
#  'clothes',
#  'covered',
#  'craft',
#  'created_by',
#  'crossing',
#  'cuisine',
#  'cycleway',
#  'denomination',
#  'description',
#  'designation',
#  'destination',
#  'destination:ref',
#  'destination:street',
#  'diet:vegan',
#  'ele',
#  'electrified',
#  'emergency',
#  'enterance',
#  'entrance',
#  'exit_to',
#  'fee',
#  'fire_hydrant:type',
#  'fixme',
#  'foot',
#  'footway',
#  'frequency',
#  'gnis:Class',
#  'gnis:County',
#  'gnis:County_num',
#  'gnis:ST_alpha',
#  'gnis:ST_num',
#  'gnis:county_id',
#  'gnis:county_name',
#  'gnis:created',
#  'gnis:feature_id',
#  'gnis:id',
#  'gnis:import_uuid',
#  'gnis:reviewed',
#  'gnis:state_id',
#  'golf',
#  'golf:course',
#  'healthcare',
#  'healthcare:speciality',
#  'hgv',
#  'hgv:national_network',
#  'hgv:state_network',
#  'highway',
#  'horse',
#  'import_uuid',
#  'is_in',
#  'is_in:city',
#  'is_in:country',
#  'is_in:country_code',
#  'is_in:state',
#  'is_in:state_code',
#  'landuse',
#  'lanes',
#  'lanes:backward',
#  'lanes:forward',
#  'latitude',
#  'layer',
#  'lcn',
#  'leaf_type',
#  'leisure',
#  'level',
#  'light',
#  'lit',
#  'location',
#  'longitude',
#  'man_made',
#  'maxspeed',
#  'maxspeed:advisory',
#  'maxspeed:trailer',
#  'mooring',
#  'motor_vehicle',
#  'name',
#  'name:en',
#  'name_1',
#  'natural',
#  'note',
#  'old_ref',
#  'oneway',
#  'oneway:bicycle',
#  'opening_hours',
#  'operator',
#  'park_ride',
#  'parking',
#  'parking:lane:right',
#  'phone',
#  'pipeline',
#  'place',
#  'placement',
#  'power',
#  'public_transport',
#  'railway',
#  'ref',
#  'religion',
#  'sangis:BASENAME',
#  'sangis:OBJECTID',
#  'sangis:TYPE',
#  'sanitary_dump_station:round_drain',
#  'seamark',
#  'seamark:beacon_special_purpose:colour',
#  'seamark:fog_signal:category',
#  'seamark:fog_signal:period',
#  'seamark:light:character',
#  'seamark:light:colour',
#  'seamark:light:height',
#  'seamark:light:period',
#  'seamark:light:range',
#  'seamark:name',
#  'seamark:reference',
#  'seamark:topmark:colour',
#  'seamark:topmark:colour_pattern',
#  'seamark:topmark:shape',
#  'seamark:type',
#  'service',
#  'shelter',
#  'shelter_type',
#  'shop',
#  'sidewalk',
#  'smoothness',
#  'source',
#  'source:bicycle',
#  'source:hgv:national_network',
#  'source:hgv:state_network',
#  'source:maxspeed',
#  'source:maxspeed:advisory',
#  'source:name',
#  'source_ref',
#  'sport',
#  'surface',
#  'tiger:ALAND',
#  'tiger:AREAID',
#  'tiger:AWATER',
#  'tiger:COUNTYFP',
#  'tiger:STATEFP',
#  'tiger:cfcc',
#  'tiger:county',
#  'tiger:name_base',
#  'tiger:name_base_1',
#  'tiger:name_base_2',
#  'tiger:name_direction_prefix',
#  'tiger:name_direction_prefix_1',
#  'tiger:name_direction_suffix',
#  'tiger:name_type',
#  'tiger:name_type_1',
#  'tiger:reviewed',
#  'tiger:separated',
#  'tiger:source',
#  'tiger:tlid',
#  'tiger:upload_uuid',
#  'tiger:zip_left',
#  'tiger:zip_left_1',
#  'tiger:zip_right',
#  'tiger:zip_right_1',
#  'toll',
#  'topmark',
#  'tourism',
#  'traffic_calming',
#  'traffic_sign',
#  'traffic_signals',
#  'trail_visibility',
#  'tunnel',
#  'turn:lanes',
#  'turn:lanes:backward',
#  'turn:lanes:forward',
#  'url',
#  'usage',
#  'voltage',
#  'water',
#  'waterway',
#  'website',
#  'wheelchair']

# %% [markdown]
# # Finding values(tag attrib['v]) for unique k (tag attrib['k]) and making observation about the data

# %%
#Finding values(tag attrib['v]) for unique k (tag attrib['k]) and making observation about the data

def values_for_unique_keys(filename):

        '''
        # Manually provide the item_name value from the list of distinct_keys to calculate 
        # the values for the corresponding unique key value. We would initialize the key 
        # variable with one value at a time and without iterating so that we could have an idea
        # of what sort of values are there for corresponding key value. Also, we would not iterate
        # as it would a long amount of time to calculate the values for all the corresponding unique
        # key value
        '''
        
        key='addr:street'
        values=[]
        EL=get_element(filename, tags=('node', 'way', 'relation'))
        for element in EL:
            for tag in element.iter('tag'):
                if tag.attrib['k']==key:
                    values.append(tag.attrib['v'])
            element.clear()
        print key
        pprint.pprint(values)

        '''
        Using Sample file as input to audit the addr:street key
        '''
values_for_unique_keys(SAMPLE_FILE)  # Using Sample file as input to audit the addr:street key
# Out:
# addr:street
# ['West Broadway',
#  '34th Street',
#  'University Avenue',
#  'Otay Mesa Road',
#  'Balboa Avenue',
#  'Columbia Street',
#  'N Avenue',
#  'Carnegie Street',
#  'East Manor Drive',
#  'Lawndale Road',
#  'Alaquinas Drive',
#  'Pomona Avenue',
#  'Oliver Avenue',
#  'Proctor Place',
#  'Cheames Way',
#  'Edgeware Road',
#  'D Avenue',
#  'Thermal Avenue',
#  'Ferndale Street',
#  'Moorpark Street',
#  'Blue Lake Drive',
#  'Longwood Street',
#  'Kendall Street',
#  'Greenford Drive',
#  'Crossroads Street',
#  'Pepper Glen Way',
#  'Challenger Circle',
#  'Garston Street',
#  'Collegio Drive',
#  'Hilltop Drive',
#  'Glasgow Drive',
#  'Cape May Avenue',
#  'Gem Tree Way',
#  'Remington Road',
#  'Harbin Place',
#  'Orozco Road',
#  'Adams Avenue',
#  'F Avenue',
#  '46th Street',
#  'Calle del Amor',
#  'Subol Court',
#  'Helix Street',
#  'Balboa Vista Drive',
#  'Willow Street',
#  'Felton Street',
#  'Pacific Avenue',
#  'Hemingway Avenue',
#  'Catalina Place',
#  'Naranca Avenue',
#  'Lake Murray Boulevard',
#  'Thorn Street',
#  'Manhasset Drive',
#  'North 1st Street',
#  'Olive Court',
#  'South 42nd Street',
#  'Linda Way',
#  'Chula Vista Street',
#  'East 11th Street',
#  'Crooked Trail Road',
#  'Caminito Primavera',
#  'Catspaw Cape',
#  'Adobe Falls Road',
#  '33rd Street',
#  'El Cajon Boulevard',
#  'Elm Avenue',
#  'El Cajon Boulevard',
#  'Valencia Parkway',
#  'Pebble Beach Drive',
#  'Davidson Avenue',
#  'Caffey Lane',
#  'Granada Avenue',
#  'Putter Drive',
#  'Crann Avenue',
#  'Jackie Drive',
#  'Pryor Drive',
#  'Indiana Street',
#  'Yosemite Street',
#  'Boulevard Place',
#  '41st Street',
#  'Kaanapali Way',
#  'Homewood Place',
#  '49th Street',
#  'Escuela Street',
#  'Alpine Avenue',
#  'Allbill Way',
#  'Elrose Court',
#  'Spruce Street',
#  'Ruffin Road',
#  'Petaluma Drive',
#  'Saint Germain Road',
#  '9th Street',
#  'East Washington Avenue',
#  'Isthmus Court',
#  'El Nopal',
#  'Adobe Falls Road',
#  'Massachusetts Avenue',
#  'Preece Street',
#  'Aragon Drive',
#  'Westby Street',
#  'Gwynne Avenue',
#  'Ash Avenue',
#  'Towne Centre Drive',
#  'Redlands Place',
#  'Caminito de la Luna',
#  'Scimitar Drive',
#  'Herman Avenue',
#  'Coleman Avenue',
#  'Jemez Drive',
#  'Camphor Court',
#  'Diza Road',
#  'Pinecrest Avenue',
#  'Regis Avenue',
#  'El Cajon Boulevard',
#  'Niagara Avenue',
#  'Chateau Court',
#  'Forward Street',
#  'Huggins Street',
#  'Hanford Drive',
#  'Menard Street',
#  'Carolina Street',
#  'Calavo Drive',
#  'Wichita Avenue',
#  'Madden Court',
#  'Stanislaus Drive',
#  'Avocado Avenue',
#  'Lantana Avenue',
#  '1st Avenue',
#  'Aliso Court',
#  '31st Street',
#  'Arruza Street',
#  'Caminito Estrella',
#  'Norman Lane',
#  'East Naples Street',
#  'Ridge Manor Avenue',
#  'Ingraham Street',
#  'Glenroy Street',
#  'Fulton Street',
#  'Kings View Court',
#  'Caminito Cachorro',
#  'Ashby Street',
#  'Albemarle Street',
#  '33rd Place',
#  'Orange Street',
#  'Clay Avenue',
#  'East Rienstra Street',
#  'Manzana Way',
#  'Jefferson Avenue',
#  'Porte la Paz',
#  'Bridgeview Drive',
#  'Avenida Circo',
#  'Whitsett Drive',
#  'Via Regla',
#  'Illion Street',
#  'College Place',
#  'Mount Jeffers Avenue',
#  'Hicock Street',
#  '20th Street',
#  'Aberdeen Street',
#  'Tommy Drive',
#  'Corte Condesa',
#  'Wildwood Road',
#  'Saratoga Avenue',
#  'Key Lane',
#  'Tone Lane',
#  'Bragg Street',
#  'Middle Fork Place',
#  'Emory Street',
#  'Centre Street',
#  'Westinghouse Street',
#  'North Harbison Avenue',
#  'Randall Street',
#  'La Jolla Boulevard',
#  'Riviera Pointe Street',
#  'Redding Road',
#  'Denver Street',
#  'Silverton Avenue',
#  'Cleveland Avenue',
#  'Del Mar Avenue',
#  'South 39th Street',
#  'Patos Place',
#  'Baroque Lane',
#  'Agosto Street',
#  'Olive Street',
#  'Vomac Road',
#  'Saint Andrews Avenue',
#  'Santa Margarita Street',
#  'Hughes Street',
#  'Jennifer Street',
#  'Madison Avenue',
#  'Vista Way',
#  'Cass Street',
#  'Marine Street',
#  'East 20th Street',
#  'Highland Avenue',
#  'Carnegie Way',
#  'Earl Street',
#  'Beatrice Street',
#  'Arbodar Road',
#  'Lange Avenue',
#  'Ronda Avenue',
#  'Tarragona Drive',
#  'Arlington Street',
#  'Olive Street',
#  '1st Avenue',
#  'Lamar Street',
#  '23rd Street',
#  'Central Avenue',
#  'Beaumont Avenue',
#  'Lynda Place',
#  'North Cuyamaca Street',
#  'Broadway',
#  'Aegean Way',
#  'Kenosha Avenue',
#  'Via Picante',
#  'Morena Boulevard',
#  'Spanish Oak Place',
#  'Central Avenue',
#  'Julia Court',
#  'Linnet Street',
#  'Clairemont Mesa Boulevard',
#  'Venters Drive',
#  'Arce Court',
#  'Goldfinch Street',
#  'Kostner Drive',
#  'South 43rd Street',
#  'Garrett Avenue',
#  'Birkdale Way',
#  'Akins Avenue',
#  'Stonecrest Boulevard',
#  'Palomar Avenue',
#  'Sweetwater Road',
#  'Fontaine Street',
#  'Calavo Drive',
#  'Yosemite Street',
#  'Weaverville Street',
#  'Lindenwood Drive',
#  'Auburn Drive',
#  '69th Street',
#  'Galahad Road',
#  'Jamacha Road',
#  'Donax Avenue',
#  '54th Street',
#  'York Court',
#  'Muir Avenue',
#  'Calle Casas Bonitas',
#  'Trias Street',
#  'Paisley Street',
#  'Stargaze Drive',
#  'Syracuse Avenue',
#  'Cerritos Court',
#  'Ledgeside Lane',
#  'Diamond Drive',
#  'Mount Ariane Drive',
#  'Ainsley Road',
#  'South 45th Street',
#  'Belardo Drive',
#  'East 1st Street',
#  'Sunnyland Avenue',
#  'Calle Cumbre',
#  'Ingraham Street',
#  'Theresa Way',
#  'El Cajon Boulevard',
#  'Amherst Street',
#  'Berkwood Drive',
#  'Eleanor Place',
#  'Mount Acadia Boulevard',
#  'Monroe Avenue',
#  'North Court',
#  'Hamlet Avenue',
#  '59th Street',
#  'North Avenue',
#  'Soderblom Avenue',
#  'Bernita Road',
#  'Alton Place',
#  'Lindbergh Street',
#  'Imperial Beach Boulevard',
#  'Millikin Avenue',
#  'East 16th Street',
#  'Vancouver Avenue',
#  'Shaw Street',
#  'Grand Teton Way',
#  'Tropico Drive',
#  'San Remo Road',
#  '5th Avenue',
#  'Gold Coast Drive',
#  'Arboretum Place',
#  'Donner Street',
#  'Town Center Parkway',
#  'Long Branch Avenue',
#  'Pepper Tree Road',
#  'Loma Rancho Drive',
#  'Nancy Ridge Drive',
#  'El Jardin Court',
#  'Willamette Avenue',
#  'Muir Avenue',
#  'Golden Sands Place',
#  'Donnington Way',
#  'Park Grove Court',
#  'Nagel Street',
#  'Caminito Velasco',
#  'Poole Street',
#  'Kandace Way',
#  'Desty Court',
#  'Chelsea Avenue',
#  'North Valley View Drive',
#  'Dragonfly Street',
#  'Huron Avenue',
#  'Amaryllis Drive',
#  'Abuela Drive',
#  'Lansing Drive',
#  'Liggett Drive',
#  'Putter Drive',
#  'Altamont Road',
#  'Akard Street',
#  'Coolidge Street',
#  'Utah Street',
#  'Quadra Avenue',
#  'Eileen Street',
#  'Hamilton Street',
#  'India Street',
#  'Jennings Street',
#  'East 24th Street',
#  'Diamond Street',
#  'Grace Road',
#  'Basswood Avenue',
#  'Haveteur Way',
#  'Bella Pacific Row',
#  'Fesler Street',
#  'D Avenue',
#  'East 30th Street',
#  'Thorn Street',
#  'Mendocino Drive',
#  'Calistoga Avenue',
#  'Dusk Drive',
#  'South 35th Street',
#  'Fuerte Drive',
#  'Murray Street',
#  'Seacoast Drive',
#  'Central Avenue',
#  'Manon Street',
#  'Brant Street',
#  'Shawnee Road',
#  'Lake Murray Boulevard',
#  'Klauber Avenue',
#  'Toulouse Drive',
#  'Estrella Avenue',
#  '42nd Street',
#  'Dwight Street',
#  'Dusk Drive',
#  'Loma Valley Road',
#  'Caminito Garcia',
#  'Alto Drive',
#  'Magnus Way',
#  'Harbinson Avenue',
#  'Jackie Drive',
#  'Blossom Hill Drive',
#  'Cabernet Drive',
#  'Batista Street',
#  'Mitscher Street',
#  'Mount Frissell Drive',
#  'Mission Boulevard',
#  'Georgia Street',
#  'Santa Sierra Court',
#  'Van Nuys Street',
#  'Powderhorn Drive',
#  'Inverness Road',
#  'I Avenue',
#  'Purdue Avenue',
#  'Linda Rosa Avenue',
#  'Sumerfield Street',
#  'Caminito Cumbres',
#  'Lemarand Avenue',
#  'K Avenue',
#  'West J Street',
#  'Idaho Street',
#  'Grand Avenue',
#  'Wilson Avenue',
#  'Donax Avenue',
#  'Forest Glen Road',
#  'Wabaska Drive',
#  'Glover Avenue',
#  'Dale Avenue',
#  'Downing Street',
#  'West California Street',
#  'Santa Monica Avenue',
#  'Caminito Marcial',
#  'Cynthia Place',
#  'Governor Drive',
#  'Valner Way',
#  'Pacific Hill Street',
#  'Westport Street',
#  'Agapanthus Drive',
#  'El Monte Road',
#  'Lowewood Place',
#  'Illinois Street',
#  'Marguerita Lane',
#  'San Vicente Street',
#  'Ramona Avenue',
#  'Chicago Street',
#  'Eton Court',
#  'Madra Avenue',
#  'Len Street',
#  'Herman Avenue',
#  'West 35th Street',
#  'Broadmoor Drive',
#  'Bonita View Drive',
#  'Murat Court',
#  'Elizabeth Street',
#  'Camino la Paz',
#  'Windward Street',
#  'Upas Street',
#  'Deep Dell Road',
#  'East 1st Street',
#  'Carmen Drive',
#  'Comondu Court',
#  'Rue Saint Lazare',
#  'Kenora Drive',
#  'Mills Street',
#  'Mount Blanca Drive',
#  'Yodel Lane',
#  'Vista del Valle Boulevard',
#  'Maryland Street',
#  'Glenhaven Way',
#  'Gay Rio Drive',
#  'Robbins Court',
#  'Broadview Street',
#  'Arroyo Drive',
#  'East Overlook Drive',
#  'Cullen Street',
#  'West Ivy Street',
#  'Santana Ranch Lane',
#  'Helix Street',
#  '3rd Avenue',
#  'Arbor Vitae Drive',
#  'Waite Drive',
#  'Circle Drive',
#  'Whelan Drive',
#  'Topa Hill Circle',
#  'Brucker Avenue',
#  'Coronado Avenue',
#  'Rosecrans Street',
#  '68th Street',
#  'Dewane Drive',
#  'Parkside Place',
#  'Cape May Avenue',
#  'Monserate Avenue',
#  'Eastridge Drive',
#  'Academy Place',
#  'Vista Grande Drive',
#  'Prestwick Drive',
#  'Elden Street',
#  'Mount Ainsworth Avenue',
#  'Corte Playa Merida',
#  'Mount Vernon Street',
#  'Cardeno Drive',
#  'Via Costina',
#  'Vista San Lucas',
#  'Overlook Place',
#  'Temecula Street',
#  'Van Dyke Avenue',
#  'Granite Springs Drive',
#  'Polk Avenue',
#  'Martha Street',
#  'Hemlock Street',
#  'Center Street',
#  'Bannock Avenue',
#  'Darwell Court',
#  'Westleigh Place',
#  'Trumbull Street',
#  'Grape Street',
#  'Wing Span Drive',
#  'Chantilly Avenue',
#  'King Kelly Drive',
#  'Aztec Drive',
#  'Padera Court',
#  'Domer Road',
#  'Pacifica Avenue',
#  'Saddle Drive',
#  'Mount Vernon Street',
#  'Layla Court',
#  'Gotham Street',
#  'Lake Alturas Avenue',
#  'Mission Avenue',
#  'Highlands Boulevard',
#  'College Avenue',
#  'Herman Avenue',
#  'Vancouver Avenue',
#  'Elm Avenue',
#  'Rio Plato Court',
#  'Adams Avenue',
#  'Via del Mesonero',
#  'Wilbur Avenue',
#  'Beaver Lake Drive',
#  'Emerald Grove Avenue',
#  'T Street',
#  'Plaza del Cid',
#  'Sandal Lane',
#  'Joshua Creek Place',
#  'Escondido Avenue',
#  'Thorne Drive',
#  'Hacienda Drive',
#  'Queen Avenue',
#  'Gregory Street',
#  'Enders Avenue',
#  'Dennstedt Court',
#  'Sierra Way',
#  'Calico Street',
#  'Ocean View Boulevard',
#  'C Avenue',
#  'Whitsett Drive',
#  'South San Jacinto Drive',
#  'North Slope Terrace',
#  'San Miguel Avenue',
#  'Ray Street',
#  'Avenida Colino',
#  'Jewell Street',
#  'Bluff Place',
#  'Hamilton Street',
#  'Utica Court',
#  'Windsor Circle',
#  'Corte Playa Barcelona',
#  'Redbud Road',
#  '4th Avenue',
#  'Fuchsia Lane',
#  'Seaside Street',
#  'Poe Street',
#  'Crary Street',
#  'Gilman Drive',
#  'East 5th Street',
#  'Mount Hay Drive',
#  'Denwood Road',
#  'Mount Herbert Avenue',
#  'Charter Avenue',
#  'Pacific Beach Drive',
#  'Alameda Boulevard',
#  'Avenida Abajo',
#  'Mount Longs Drive',
#  'South 32nd Street',
#  'Bay Crest Lane',
#  'Shady Elm Place',
#  'Martha Street',
#  'Piedmont Street',
#  'Goldsmith Street',
#  'Kelburn Avenue',
#  '4th Avenue',
#  'Wrelton Drive',
#  'H Avenue',
#  'Texas Street',
#  'Morrella Street',
#  'Bellena Avenue',
#  'Fuerte Farms Road',
#  'San Rafael Place',
#  'Belford Street',
#  'South Sunshine Avenue',
#  'Katherine Street',
#  'Dixie Drive',
#  'C Avenue',
#  'Sheila Street',
#  'Spring Sky Street',
#  'Silver Sage Road',
#  'Goulburn Court',
#  'Toboggan Way',
#  'La Chica Drive',
#  'Abuela Drive',
#  'Oliver Avenue',
#  'Cimarron Way',
#  'Clearbrook Drive',
#  'Coast Boulevard South',
#  'Bayside Lane',
#  '39th Street',
#  'Cardeno Drive',
#  'Acacia Avenue',
#  'Ethan Allen Avenue',
#  'Sea Isle Drive',
#  'Tarbox Street',
#  'Shantung Drive',
#  'Lakeview Drive',
#  'Haniman Drive',
#  'Orma Drive',
#  'Cartwright Street',
#  '69th Street',
#  'Front Street',
#  'Park Boulevard',
#  '58th Street',
#  'Carlton Oaks Drive',
#  'South Marshall Avenue',
#  'Wilbur Avenue',
#  'Lawndale Road',
#  'Jackdaw Street',
#  'Covina Street',
#  'Murat Street',
#  'Jamie Avenue',
#  'Date Street',
#  'East Emerson Street',
#  'Eagle Street',
#  'Plaza Ridge Road',
#  'Sugarman Court',
#  'West Olive Street',
#  'Moss Street',
#  'Lamont Street',
#  'Hinson Place',
#  'Mercer Lane',
#  'Sunset Cliffs Boulevard',
#  'Cuvier Street',
#  'Elm Avenue',
#  'Garnet Avenue',
#  'Ivanhoe Avenue',
#  'Pequena Street',
#  'South Royal Oak Drive',
#  'Parker Mountain Road',
#  'C Street',
#  'Adams Avenue',
#  'Red Granite Road',
#  'North 2nd Street',
#  'Conner Court',
#  'Lake Breeze Court',
#  'Ohio Street',
#  'Bollenbacher Street',
#  'Sugarman Way',
#  'Diamond Street',
#  'B Avenue',
#  'Loma Drive',
#  'Westinghouse Street',
#  'Winnett Street',
#  'South 33rd Street',
#  'Ladera Street',
#  'Topaz Court',
#  'Lambda Drive',
#  'N Avenue',
#  'Carlton Oaks Drive',
#  'Ramfos Lane',
#  'Marlesta Drive',
#  'Hillslake Drive',
#  'K Avenue',
#  'Garden Grove Lane',
#  'Highlands Boulevard',
#  'Limetree Lane',
#  'Ridge View Drive',
#  'Arguello Street',
#  'Pike Road',
#  'Town Center Parkway',
#  'Corte Playa Catalina',
#  'Greenleaf Road',
#  'Via de la Bandola',
#  'Kenora Drive',
#  'Tomahawk Lane',
#  'Hacienda Drive',
#  'Mount Ashmun Drive',
#  'Prospect Street',
#  'Hidalgo Avenue',
#  'Bonita Mesa Road',
#  'Whispering Trails Drive',
#  'Char Marie Circle',
#  'Bullock Drive',
#  'Carlsbad Street',
#  'Felton Street',
#  'Wind Cave Place',
#  'Maynard Street',
#  'Sterne Street',
#  'Vista San Guadalupe',
#  'West Ash Street',
#  'Hoover Avenue',
#  'Hillandale Drive',
#  'Chandler Drive',
#  'Cape May Avenue',
#  'Warmwell Drive',
#  'Sylvia Street',
#  'Gaylord Drive',
#  'Orcutt Avenue',
#  'Phyllis Place',
#  'Menorca Drive',
#  'Edgemont Street',
#  'Matterhorn Drive',
#  'Caminito DeGrazia',
#  'Morning Breeze Lane',
#  'Altamirano Way',
#  'Mount Ariane Drive',
#  'Reynolds Street',
#  'Falcon Valley Drive',
#  'Morningside Street',
#  'Petaluma Drive',
#  'Parkside Avenue',
#  'Arenas Street',
#  'A Street',
#  'Baldwin Road',
#  'Chamoune Avenue',
#  'Olvera Avenue',
#  'Royal Gardens Place',
#  'Buisson Street',
#  'University Avenue',
#  'Caminito Mira',
#  'South Mollison Avenue',
#  'Mascari Place',
#  'Crespo Drive',
#  'College Grove Drive',
#  'Upas Street',
#  'Nabal Drive',
#  'Hoffman Avenue',
#  '6th Street',
#  'Bilteer Drive',
#  'Belle Glade Avenue',
#  'Avenida Anacapa',
#  'South Creekside Drive',
#  'Estrella Avenue',
#  'Greenfield Court',
#  'Cherokee Avenue',
#  'Kingswood Street',
#  'Lemon Avenue',
#  'Conrad Court',
#  'Nicholas Way',
#  'Coldstream Drive',
#  'Morena Boulevard',
#  'Banning Street',
#  'Armstrong Street',
#  'Melotte Street',
#  'Del Monte Avenue',
#  'Sussex Drive',
#  'Colorado Avenue',
#  'Benfield Court',
#  'Sappington Court',
#  'Mountain View Way',
#  'Colorado Avenue',
#  'Via Cedro',
#  'Ledgewood Lane',
#  'West Nutmeg Street',
#  'Denver Street',
#  'Lindenwood Drive',
#  'Jefferson Avenue',
#  'Lemon Avenue',
#  'El Paseo Grande',
#  'Belloc Court',
#  'Iris Avenue',
#  'Granada Avenue',
#  'Worthington Street',
#  'Parthenon Drive',
#  'Bonair Street',
#  'Calico Street',
#  'Black Oak Road',
#  '50th Street',
#  'Oregon Street',
#  'Jalal Street',
#  'Evergreen Road',
#  'San Diego Avenue',
#  'Oak Creek Drive',
#  'Corte de Cera',
#  'Harrison Avenue',
#  'Gaylord Court',
#  'Gaylord Drive',
#  'Queen Avenue',
#  'Dartmoor Drive',
#  'East 30th Street',
#  'Sea Maid Court',
#  'Nobel Drive',
#  'Leonard Street',
#  '3rd Avenue',
#  'Lincoln Avenue',
#  'Carancho Street',
#  'Don Pico Road',
#  'Madrona Street',
#  'Nagel Street',
#  'Gem Tree Way',
#  'Peach Avenue',
#  'Florida Street',
#  'Tokalon Street',
#  'Santa Cruz Avenue',
#  'Rue Cannes',
#  'Lynn Street',
#  'Conrad Avenue',
#  'East Mountain View Drive',
#  'Alabama Street',
#  'Steel Street',
#  'Elm Avenue',
#  'Wilbur Avenue',
#  'Russan Lane',
#  'East 2nd Street',
#  '12th Street',
#  'Caminito Floreo',
#  'Montcalm Street',
#  'Ebony Avenue',
#  'Lamar Street',
#  'Kadwell Way',
#  '1st Avenue',
#  'Firethorn Street',
#  'Clearcreek Place',
#  'Adams Avenue',
#  'Central Avenue',
#  'Halsey Street',
#  'East Madison Avenue',
#  'Carlton Oaks Drive',
#  'Fort Stockton Drive',
#  'East 7th Street',
#  'Bram Avenue',
#  'South 31st Street',
#  'Catamarca Drive',
#  'Hortensia Street',
#  'Hill Drive',
#  'Lancaster Drive',
#  'Royal Greens Place',
#  'Everview Road',
#  'Camino del Rey',
#  'Palm Avenue',
#  'Sapota Drive',
#  'La Jolla Rancho Road',
#  'El Cajon Boulevard',
#  'King Street',
#  'Leland Street',
#  'Cliffridge Lane',
#  '9th Avenue',
#  'Fino Drive',
#  'Tarbox Street',
#  'Murray Hill Road',
#  'Bramblewood Street',
#  'Glenroy Street',
#  'Budd Street',
#  'Meadow Lark Drive',
#  'Linda Vista Road',
#  'Moonstone Place',
#  'Caminito Terviso',
#  'Bethany Place',
#  'Stresemann Street',
#  'Franklin Avenue',
#  'Bryanview Circle',
#  'Tribuna Avenue',
#  'Donax Avenue',
#  'Westbourne Street',
#  'Adams Avenue',
#  'Birchwood Street',
#  'Dunaway Drive',
#  'Tommy Drive',
#  'Montemar Drive',
#  'Alta Drive',
#  'Mansfield Street',
#  'Lindo Lane',
#  'North Westwind Drive',
#  'Skyline Drive',
#  'Lake Ben Avenue',
#  'Cottonwood Avenue',
#  'Adair Street',
#  'Valva Avenue',
#  'Herman Avenue',
#  'Grove Street',
#  'Meade Avenue',
#  'Newton Avenue',
#  'San Anselmo Street',
#  'Via Casa Alta',
#  'Pomona Avenue',
#  'Briand Avenue',
#  'Long Branch Avenue',
#  'Altadena Avenue',
#  'East J Street',
#  'Poplar Street',
#  'Orange Avenue',
#  'Oaklawn Avenue',
#  'Palm Avenue',
#  'Calle Naranja',
#  'Drumcliff Avenue',
#  'Ramona Avenue',
#  'Calgary Avenue',
#  'Alta Vista Street',
#  'Honey Drive',
#  'E Avenue',
#  'El Capitan Drive',
#  'Columbia Street',
#  '40th Street',
#  'Alejo Street',
#  '40th Street',
#  'Nordica Avenue',
#  'Viacha Way',
#  'Barbic Lane',
#  'Eldergardens Street',
#  'Austin Drive',
#  'Medical Center Drive',
#  'Jacumba Street',
#  'Mansfield Street',
#  'Northcote Road',
#  'Clearcreek Place',
#  'Ridge Manor Avenue',
#  'Anza Court',
#  'Rancho Park Drive',
#  'Vance Street',
#  '32nd Street',
#  'Hilger Street',
#  'Gunzan Street',
#  'Waterfall Place',
#  'Newberry Street',
#  'Ocala Court',
#  'Waterbury Drive',
#  'Goetschl Street',
#  'Wawona Drive',
#  'Laurie Lane',
#  'Cherokee Avenue',
#  'Leathers Street',
#  '41st Street',
#  'Bellvale Avenue',
#  'North Rogers Road',
#  'Dorchester Street',
#  'Orange Court',
#  'Spinnaker Way',
#  'Rio Camino',
#  '1st Street',
#  'Myrtle Avenue',
#  'Norfolk Street',
#  'Oakhurst Drive',
#  'Monroe Avenue',
#  'Oneonta Avenue',
#  'White Alder Avenue',
#  'Luna Avenue',
#  'Hillgrove Drive',
#  'Kramer Street',
#  'Camino Entrada',
#  'Plymouth Court',
#  'Gem Tree Way',
#  'Loma del Sol Drive',
#  'Mount Abraham Avenue',
#  'Carthage Street',
#  '3rd Street',
#  'Marlborough Avenue',
#  'Princess Marcie Drive',
#  'Porto Court',
#  'Lantana Drive',
#  'Caminito Amparo',
#  'Madison Avenue',
#  'Chollas Parkway',
#  'Ohio Street',
#  'Dakota Drive',
#  'Agate Street',
#  'Kappa Street',
#  'Alpha Street',
#  'Cartwright Street',
#  'Spring Oak Way',
#  'Shannonbrook Court',
#  'Paraiso Avenue',
#  'Ironwood Road',
#  'Jamacha Road',
#  'Del Mar Avenue',
#  'Cowley Way',
#  'Riviera Summit Road',
#  'Crooked Path Place',
#  'Heatherdale Street',
#  'Wellesley Street',
#  '33rd Place',
#  'Ruby Street',
#  'Lairwood Drive',
#  'Promesa Drive',
#  'Ramona Avenue',
#  'Amberly Street',
#  'Hazard Center Drive',
#  'East Palomar Street',
#  'Grape Street',
#  'Avati Drive',
#  'Live Oak Drive',
#  '46th Street',
#  'Rue de Roark',
#  'Coyote Ridge Terrace',
#  'Manzana Way',
#  'Lemon Crest Drive',
#  'Clairemont Drive',
#  'Celia Vista Drive',
#  '2nd Avenue',
#  'Mohawk Street',
#  'Kerrigan Court',
#  '35th Street',
#  '5th Avenue',
#  'Villa Terrace',
#  'Appleton Street',
#  'Hotz Street',
#  'Fontaine Street',
#  'Denver Street',
#  'Dunning Circle',
#  'Lehrer Drive',
#  'Foothill Boulevard',
#  'Caminito Estrellado',
#  'Holly Avenue',
#  'Lewiston Place',
#  'Posthill Road',
#  'Lamar Street',
#  'Jellett Street',
#  'Wightman Street',
#  'Ramona Avenue',
#  'Monroe Avenue',
#  'East 11th Street',
#  'Zorita Court',
#  'Madera Rosa Way',
#  'Mount Gaywas Drive',
#  'Central Avenue',
#  'Ivanhoe East Avenue',
#  'Alicia Drive',
#  '71st Street',
#  'Zion Avenue',
#  'Lehigh Avenue',
#  'Regner Road',
#  'Firethorn Street',
#  'Somermont Drive',
#  'Melbourne Drive',
#  'Dubois Drive',
#  'Indigo Canyon Road',
#  'Shadow Hill Way',
#  'Sea Water Lane',
#  'Reed Avenue',
#  'Tamarand Way',
#  'Winter Gardens Boulevard',
#  'Ocean View Boulevard',
#  'Westbrook Avenue',
#  'San Miguel Avenue',
#  'Deerhollow Place',
#  'Fuerte Drive',
#  'Circulo Margen',
#  'Illinois Street',
#  'Englewood Drive',
#  'Southview Drive',
#  'Edgemont Street',
#  'Garrett Avenue',
#  'Fury Lane',
#  'Flower Street',
#  'Eldridge Court',
#  'East 16th Street',
#  'Mount Aachen Avenue',
#  'Comstock Street',
#  'Avocado Village Court',
#  'La Mesa Boulevard',
#  'High Street',
#  'Mohler Street',
#  '60th Street',
#  'Garywood Street',
#  'Bunker Hill Street',
#  'Jamacha Boulevard',
#  'Apache Drive',
#  'Mendota Street',
#  'Florida Street',
#  'La Jolla Hermosa Avenue',
#  'Marina Avenue',
#  '22nd Street',
#  'Illion Street',
#  'Cobb Court',
#  'Friedrick Drive',
#  'Carol Place',
#  'Toledo Drive',
#  'La Jolla Boulevard',
#  'Ivy Street',
#  'Newton Avenue',
#  'Camrose Avenue',
#  'South Mollison Avenue',
#  'Reservoir Lane',
#  'Acero Street',
#  'Sea Strand Lane',
#  'Dissinger Avenue',
#  'Calle Mesita',
#  'Sawtelle Avenue',
#  'Pearlwood Road',
#  'Olivewood Terrace',
#  'Thomas Avenue',
#  'Mount Frissell Drive',
#  'Tomiko Court',
#  'Fanita Rancho Road',
#  'Federal Boulevard',
#  'Nebo Drive',
#  'Palm Avenue',
#  'Chickasaw Court',
#  'Commonwealth Avenue',
#  'Marline Avenue',
#  'Fuerte Drive',
#  'Paula Street',
#  'Mount Alifan Drive',
#  'Beaumont Drive',
#  'Royal Gorge Drive',
#  'L Street',
#  'Ivanhoe Avenue',
#  'Pauling Avenue',
#  'Macaulay Street',
#  'Avocet Court',
#  'Vancouver Avenue',
#  'Lake Forest Avenue',
#  'Oleander Avenue',
#  'Pacific Beach Drive',
#  'Lemon Avenue',
#  'Helix Avenue',
#  'Riverview Avenue',
#  'Herman Avenue',
#  'Portsmouth Drive',
#  'Green Lane',
#  'Corte Playa Pacifica',
#  'Leanna Street',
#  'Prospect Street',
#  'Sumac Drive',
#  'Revillo Drive',
#  'Caminito Joven',
#  'South Marshall Avenue',
#  'Mount Frissell Drive',
#  'Shady Sands Road',
#  'Alderbrook Place',
#  'Via del Bardo',
#  'Oakpoint Avenue',
#  'Chelsea Park Circle',
#  'Fuerte Drive',
#  'Noble Street',
#  'Olive Street',
#  'Montgomery Street',
#  'Peach Blossom Street',
#  'Little Leaf Lane',
#  'Via de la Bandola',
#  'Monte Verde Drive',
#  'Monserate Avenue',
#  '1st Avenue',
#  'Topaz Lake Avenue',
#  'Ocean Boulevard',
#  'K Street',
#  'Gorge View Terrace',
#  'Alcala Knolls Drive',
#  'Chicago Street',
#  'Veracruz Court',
#  'Ramsay Avenue',
#  'Pershing Avenue',
#  'Waterville Lake Road',
#  'Elm Street',
#  'South Paradise Ridge Way',
#  'Calle Miramar',
#  'Bayview Heights Drive',
#  'Capehart Street',
#  'Citrus Street',
#  'Balboa Avenue',
#  'Aaron Court',
#  'Caminito Ocio',
#  'Normandie Place',
#  'Creekford Drive',
#  'Hoover Avenue',
#  'Granite Hills Drive',
#  'Corte Maria Avenue',
#  'Amador Street',
#  'Grand Avenue',
#  'Rainier Court',
#  'Cather Avenue',
#  'Wolviston Way',
#  'Careybrook Lane',
#  'King Street',
#  'Woodridge Way',
#  'Barstow Street',
#  'Crescent Drive',
#  'Cypress Avenue',
#  'Old Bridgeport Way',
#  'Topsail Drive',
#  'Fairbrook Road',
#  'Loch Lomond Street',
#  'Ocala Avenue',
#  'Caminito Pan',
#  '8th Avenue',
#  'Quiet Trail Drive',
#  'Flanders Drive',
#  'Park West Lane',
#  'Alta Bahia Court',
#  'Missouri Street',
#  'Birdsong Place',
#  'Archer Street',
#  'Mission Bonita Drive',
#  'Randlett Drive',
#  'Eldora Street',
#  'Savoy Street',
#  'Ohio Street',
#  'Copper Penny Drive',
#  'Agate Street',
#  'Mesa College Drive',
#  'Twin Oaks Avenue',
#  'Ravenwood Drive',
#  'Lucille Drive',
#  'Lincoln Avenue',
#  'Vista Way',
#  'Imperial Beach Boulevard',
#  'Harris Street',
#  'Elliott Street',
#  'Ritchey Street',
#  'Church Avenue',
#  'Jade Coast Road',
#  'Max Avenue',
#  'Collinwood Drive',
#  'Hiawatha Way',
#  'Robb Roy Place',
#  'Wilfred Street',
#  'Larkhaven Drive',
#  'Elm Street',
#  'K Street',
#  'Hayes Street',
#  'Eucalyptus Court',
#  'Joey Avenue',
#  'National Avenue',
#  'Garfield Street',
#  'Glencoe Drive',
#  'Calle Aguadulce',
#  'Calle del Oro',
#  'Pacifica Drive',
#  'Lake Arrowhead Drive',
#  'Cecelia Terrace',
#  'Via Ladeta',
#  'Broadway',
#  'Springfield Street',
#  'Friant Street',
#  'Oneonta Avenue',
#  'Wahl Street',
#  'Camino Aleta',
#  'Harris Avenue',
#  'Escobar Drive',
#  'Swift Avenue',
#  'Vandever Avenue',
#  'Proctor Place',
#  'Talbot Street',
#  'Limerick Avenue',
#  '12th Street',
#  'Mariposa Circle',
#  'Woodburn Street',
#  'Renaissance Avenue',
#  'Santa Maria Court',
#  'Friars Road',
#  'Estelle Street',
#  'Cuyamaca Avenue',
#  'Sumac Drive',
#  'Eastridge Drive',
#  'South 40th Street',
#  'Orchard Road',
#  'Roanoke Street',
#  'Via Temprano',
#  'Calavo Drive',
#  'Clairemont Drive',
#  'Bancroft Drive',
#  'Calle Cumbre',
#  'Madera Rosa Way',
#  '1st Avenue',
#  'Harvala Street',
#  'Courtyard Drive',
#  'East Oxford Street',
#  'East Main Street',
#  'Lipmann Street',
#  'Guilitoy Avenue',
#  'El Granito Avenue',
#  'Kardeelin Court',
#  'Toyne Street',
#  'Dawnridge Avenue',
#  'Seminole Drive',
#  'Copley Avenue',
#  'Beagle Street',
#  'Pueblo Road',
#  'Baroness Avenue',
#  'Wheatville Street',
#  'Wykes Street',
#  'I Street',
#  'East Main Street',
#  'Foss Street',
#  'Front Street',
#  'C Avenue',
#  'Mandeville Road',
#  'Merlin Drive',
#  'Beatrice Street',
#  'Maranda Drive',
#  'Woodlawn Avenue',
#  'Noeline Place',
#  'Roseland Drive',
#  'Driscoll Drive',
#  'C Street',
#  'Skylark Way',
#  'Aaron Court',
#  'California Waters Drive',
#  'Hilltop Drive',
#  'Casselman Place',
#  'Cable Street',
#  'Utah Street',
#  'Marysville Avenue',
#  'Baja Drive',
#  'National Avenue',
#  'Glacier Avenue',
#  'Scarlati Place',
#  'West C Street',
#  'Carlsbad Street',
#  'Heatherdale Street',
#  'La Jolla Rancho Road',
#  'Jackson Drive',
#  'Braun Avenue',
#  'Plaza Calimar',
#  'Harjoan Avenue',
#  'River Street',
#  'Via Antigua',
#  'Broadway',
#  'Rookwood Drive',
#  'Rosecroft Lane',
#  'Grand Avenue',
#  'Esmeraldas Drive',
#  'Clara Lee Avenue',
#  'Bonair Way',
#  'Maple Drive',
#  'Aspen Glen Road',
#  'Madden Avenue',
#  '29th Street',
#  'Westhill Road',
#  'Nile Street',
#  'Bathurst Place',
#  'Bayonne Drive',
#  'Morgan Hill Drive',
#  'Mary Lane Drive',
#  'Erie Street',
#  'Resmar Road',
#  'Crown Point Court',
#  'Seagreen Place',
#  'Sumner Avenue',
#  'Edgeware Road',
#  'Jackson Hill Drive',
#  'Kimmy Court',
#  '36th Street',
#  'Tamilynn Street',
#  'La Cuenta Drive',
#  'Milan Street',
#  'Gayneswood Way',
#  'Frisbie Street',
#  'Corrales Lane',
#  'Calle de Medio',
#  'Kelburn Avenue',
#  'Lambert Lane',
#  'Chapo Court',
#  'Wenatchee Avenue',
#  'La Presa Avenue',
#  'Baxter Street',
#  'Lemon Avenue',
#  'Manhattan Court',
#  'La Presa Avenue',
#  '50th Street',
#  'San Carlos Drive',
#  'Ingraham Street',
#  'Iris Avenue',
#  'K Street',
#  'Melrose Avenue',
#  'Devon Court',
#  'Elm Avenue',
#  '44th Street',
#  'Oregon Street',
#  'Nagel Street',
#  'Westhill Road',
#  'El Paso Street',
#  'Vista San Carlos',
#  'Twining Avenue',
#  'East Park Avenue',
#  'Summit Avenue',
#  'Ivory Court',
#  'Paseo Rosal',
#  'Volcano Creek Road',
#  'Schuyler Avenue',
#  'Citrus Avenue',
#  'Renovo Way',
#  '3rd Avenue',
#  'Rockcrest Road',
#  'Orchard Avenue',
#  'Sandstone Drive',
#  'A Street',
#  'Delta Street',
#  'Narragansett Avenue',
#  'Udall Street',
#  'Reichert Way',
#  'E Avenue',
#  'Marzo Street',
#  'Williams Court',
#  'Pola Court',
#  'Joey Avenue',
#  'Vista San Matias',
#  'Lincoln Avenue',
#  'Teasdale Avenue',
#  'Hewlett Drive',
#  'Agate Street',
#  'Trocha de Penni',
#  'Cactusridge Street',
#  'Georgina Street',
#  'Avenida Sanchez',
#  'Sandpiper Strand',
#  'Winter Gardens Boulevard',
#  'Corral Canyon Road',
#  'Via Alcazar',
#  'Lance Avenue',
#  'Stoyer Drive',
#  'Abbeywood Road',
#  'Buckeye Drive',
#  'Halberns Boulevard',
#  'Dawes Street',
#  'Reagan Place',
#  'Woodside Avenue',
#  'Mohawk Street',
#  'Belle Glade Avenue',
#  'Falmouth Drive',
#  'Streamview Drive',
#  '31st Street',
#  'Riverview Avenue',
#  '5th Avenue',
#  'Gem Tree Way',
#  'Spring Canyon Drive',
#  'Caminito Revueltos',
#  'Shannon Avenue',
#  'Boca Raton Drive',
#  'Hilltop Drive',
#  'Sundale Road',
#  'Silvercreek Drive',
#  'North Mollison Avenue',
#  'Lake Ashmere Drive',
#  'Myrtle Way',
#  'Arroyo Way',
#  'Olive Avenue',
#  '10th Street',
#  'Hayes Street',
#  'Dugan Avenue',
#  'Waldgrove Place',
#  'Berry Street',
#  'Valecrest Lane',
#  'Glover Avenue',
#  'My Way',
#  'Madison Avenue',
#  'Corte Maria Avenue',
#  'Russ Boulevard',
#  'Mission Boulevard',
#  'Soledad Mountain Road',
#  'Orien Avenue',
#  'Emerald Street',
#  'Beatrice Street',
#  'Castle Hills Drive',
#  'Creekside Village Way',
#  'Kearny Mesa Road',
#  'Kolmar Street',
#  'Newport Avenue',
#  'Blackshaw Lane',
#  'Caminito Luisito',
#  'E Avenue',
#  'Windsor Drive',
#  'Oregon Street',
#  'Redwing Road',
#  'Paul Jones Avenue',
#  'Mount Frissell Drive',
#  'San Antonio Avenue',
#  'Newport Avenue',
#  'Udall Street',
#  'Ingelow Street',
#  'Calle de la Plata',
#  'Strathmore Drive',
#  'Rue Avallon',
#  'Lipmann Street',
#  'Casa Place',
#  'Golden Ridge Road',
#  'Caminito Andreta',
#  'Baker Street',
#  'Pioneer Way',
#  'Richmond Street',
#  'Baily Place',
#  'Nautilus Street',
#  'Governor Drive',
#  'Cibola Road',
#  'Manzana Way',
#  'Milburn Avenue',
#  'North S Avenue',
#  'San Altos Place',
#  'Balboa Avenue',
#  'Conrad Avenue',
#  'Sorrento Valley Boulevard',
#  'Oberlin Drive',
#  'Thrasher Way',
#  'Tamarand Way',
#  'Day Creek Trail',
#  'Glidden Street',
#  'Deauville Street',
#  '34th Street',
#  'Sunset Avenue',
#  'Rookwood Drive',
#  'Marzo Street',
#  'Diane Avenue',
#  'Farragut Road',
#  'Santa Delphina Avenue',
#  'East 9th Street',
#  'Coronado Avenue',
#  'Conner Court',
#  'Cromwell Court',
#  'Cassandra Lane',
#  'Cinnabar Drive',
#  'Persimmon Avenue',
#  'Mission Avenue',
#  'Old Memory Lane',
#  '70th Street',
#  'Louisiana Street',
#  'Market Street',
#  'Channing Street',
#  'Ducommun Avenue',
#  'Potomac Street',
#  'Holly Avenue',
#  'Milden Street',
#  'East J Street',
#  'Montera Street',
#  'Sampson Street',
#  '48th Street',
#  'Jackson Drive',
#  'Seton Hall Street',
#  'Lake Andrita Avenue',
#  'Baylor Avenue',
#  'Semple Street',
#  'Silverado Drive',
#  'Cadden Way',
#  'Colusa Street',
#  'Ogden Street',
#  'Quailview Street',
#  'Euclid Avenue',
#  'Ordview Court',
#  'San Ramon Drive',
#  'Eastridge Loop',
#  'Via Amalia',
#  'Via Trieste',
#  'Vecino Court',
#  'Palm Avenue',
#  '3rd Street',
#  'Trieste Drive',
#  'West Grape Street',
#  'Farmington Drive',
#  'New Bedford Court',
#  'Toni Lane',
#  'Hartford Street',
#  '44th Street',
#  'Calle Albara',
#  'Chateau Drive',
#  '67th Street',
#  'Kelton Avenue',
#  'Crystal Lane',
#  'Caminito Basilio',
#  'Gaylord Place',
#  'Frankfort Street',
#  'Helix Street',
#  'Ithaca Street',
#  'East Hartland Circle',
#  'Columbine Street',
#  'Rowan Street',
#  'Tobias Drive',
#  'James Street',
#  'Lomacitas Lane',
#  'Barnhurst Drive',
#  '6th Avenue',
#  'Merced Lake Avenue',
#  'Blackton Drive',
#  'Wilson Avenue',
#  'Villa Bonita',
#  'Wightman Street',
#  'Eads Avenue',
#  'River Valley Court',
#  'Norman Lane',
#  'Virginian Lane',
#  'Oliver Avenue',
#  'Abbott Street',
#  'Cowles Mountain Boulevard',
#  'Vancouver Avenue',
#  'Fir Street',
#  'Park West Avenue',
#  'Lake Canyon Road',
#  'Campina Place',
#  'Campo Road',
#  'Buena Vista Drive',
#  'East 2nd Street',
#  'Buena Vista Street',
#  'Sawtelle Avenue',
#  'Mount Bullion Drive',
#  'Alcott Street',
#  'San Luis Rey Avenue',
#  'Portobelo Court',
#  'Parkbrook Way',
#  '60th Street',
#  'Clairemont Mesa Boulevard',
#  'Ashford Street',
#  'Duoro Drive',
#  'Bakewell Street',
#  'Hornblend Street',
#  'Encinitas Avenue',
#  'Deep Dell Road',
#  '55th Street',
#  'Friant Street',
#  '29th Street',
#  'Cape Cod Court',
#  'Geraldine Avenue',
#  'Polk Avenue',
#  '4th Avenue',
#  'Roselle Street',
#  'Onondaga Avenue',
#  'Geranium Street',
#  'Thrasher Way',
#  'Hickory Street',
#  'Grape Street',
#  'Marlborough Drive',
#  'Diamond Street',
#  'Van Dyke Avenue',
#  'Connecticut Street',
#  'Creighton Way',
#  'Narragansett Avenue',
#  'Deer Hollow Court',
#  'Poe Street',
#  'Mount Frissell Drive',
#  'Denver Street',
#  'Mount Ararat Drive',
#  'Clairemont Mesa Boulevard',
#  'Arthur Avenue',
#  'Long Branch Avenue',
#  'Winding Creek Drive',
#  'Thomas Avenue',
#  'Rincon Street',
#  'G Street',
#  'Ironwood Road',
#  'Mayo Street',
#  'Dewes Way',
#  'Earle Drive',
#  'Waring Road',
#  'Maple Street',
#  'Roeblin Court',
#  'Casa de la Torre Court',
#  'Cervantes Avenue',
#  'Provo Street',
#  'Calle Naranja',
#  'Carissa Court',
#  'Mahogany Vista Lane',
#  'Elroy Drive',
#  'Dartmouth Street',
#  'Duval Street',
#  'Indian Creek Place',
#  'Holly Drive',
#  'Kingswood Drive',
#  'South Barcelona Street',
#  'Helen James Avenue',
#  'Vetter Place',
#  'Hornblend Street',
#  'Olive Street',
#  'La Presa Avenue',
#  'Journey Street',
#  'Erie Street',
#  'Fulton Street',
#  'Tie Street',
#  'E Street',
#  '29th Street',
#  'New Seabury Drive',
#  'Grape Street',
#  'Lynn Place',
#  'Syracuse Avenue',
#  'Fulmar Street',
#  'Fairhill Drive',
#  'Harrison Avenue',
#  '35th Street',
#  'Pacific Beach Drive',
#  'Glencoe Drive',
#  'Hunters Pointe Avenue',
#  'El Nopal',
#  'Nancy Ridge Drive',
#  'Mount Aclare Avenue',
#  'Santo Road',
#  'Gobat Avenue',
#  'Granada Avenue',
#  'Lucinda Street',
#  'Playa del Norte',
#  'Avenida Cresta',
#  'Florida Street',
#  'South Bancroft Street',
#  'Olive Avenue',
#  'Royal Ann Avenue',
#  'Millan Street',
#  'Koe Street',
#  'Blue Lake Drive',
#  'Wendell Street',
#  'Cajon Greens Drive',
#  'West Canyon Terrace',
#  'Casita Way',
#  'Molino Road',
#  'Steiner Drive',
#  'South Creekside Drive',
#  'Topa Hill Circle',
#  'Aquamarine Road',
#  'Glen Street',
#  'Berkview Lane',
#  'Leighton Court',
#  'Cassiopeia Lane',
#  'East 28th Street',
#  'Costada Court',
#  'Prospect Avenue',
#  'Cypress Avenue',
#  'Melotte Street',
#  'Westbourne Street',
#  'West Park Avenue',
#  'Hillslope Avenue',
#  'Caulfield Drive',
#  'Crosscreek Road',
#  'Long View Drive',
#  'Wilson Avenue',
#  'Draper Avenue',
#  'Crest Drive',
#  'Blossom Hill Drive',
#  'E Avenue',
#  'Meade Avenue',
#  'Neva Avenue',
#  '3rd Street',
#  'Red Cedar Way',
#  'Doliva Drive',
#  'Saugerties Avenue',
#  'Stevenson Way',
#  'Feather River Place',
#  'Urban Drive',
#  'Dale Street',
#  'Greencrest Court',
#  'Red Granite Road',
#  'Rocket Ridge Road',
#  'Sedgewick Street',
#  'Olivetas Avenue',
#  'Lake Ridge Court',
#  'Via Miraleste',
#  'Canyon Lake Drive',
#  'Winona Avenue',
#  'Sapota Drive',
#  'Adkins Way',
#  'Dancy Road',
#  'Nelson Street',
#  'Lamar Street',
#  'Henderson Drive',
#  'Alpine Avenue',
#  'Richmond Street',
#  'Orlando Court',
#  'Los Altos Drive',
#  'Redland Drive',
#  'Wildwood Road',
#  'Picket Fence Drive',
#  'Barton Peak Drive',
#  'Talon Way',
#  'North Johnson Avenue',
#  'Winter Gardens Drive',
#  'Reynolds Street',
#  'La Costa Avenue',
#  'Madera Rosa Way',
#  'Santa Margarita Street',
#  'Menlo Avenue',
#  'Avenida Ladera',
#  'Malta Avenue',
#  'East 4th Street',
#  'Long View Drive',
#  'Sierra Vista Avenue',
#  'Ramona Avenue',
#  'Maine Avenue',
#  'North Mountain View Drive',
#  'Versailles Road',
#  'Osprey Street',
#  'Carroll Canyon Road',
#  'Dalehurst Road',
#  'Manzanita Drive',
#  'Texas Street',
#  'South Siena Street',
#  'Haines Street',
#  'Big Cone Drive',
#  'Trace Road',
#  'Winter Gardens Boulevard',
#  'Pavlov Avenue',
#  'Margarita Avenue',
#  'Donax Avenue',
#  'Voltaire Street',
#  'Carlsbad Court',
#  'East 4th Street',
#  'Kansas Street',
#  'Utah Street',
#  'West Street',
#  'Raven Avenue',
#  'West Muirlands Drive',
#  'Port Cardiff',
#  'Grand Avenue',
#  'Florida Street',
#  'South 35th Street',
#  'Cuyamaca Avenue',
#  'Pepper Drive',
#  'Adobe Drive',
#  'Cowles Mountain Boulevard',
#  'Sandalwood Drive',
#  'La Jolla Farms Road',
#  'North Drexel Avenue',
#  '31st Street',
#  'Campanile Way',
#  'North Magnolia Avenue',
#  'Old Bridgeport Way',
#  'Aaron Way',
#  'Marbella Circle',
#  '70th Street',
#  'Maria Avenue',
#  'Mobley Street',
#  'Harbour Town Place',
#  'Banneker Drive',
#  'Dunwoodie Road',
#  'Marquis Court',
#  'Redwood Street',
#  'Camino de la Costa',
#  'Redcrest Drive',
#  'Uvalde Court',
#  'Varney Drive',
#  'Landis Street',
#  'East Washington Avenue',
#  'Manzana Way',
#  'Missouri Street',
#  'Gilmartin Drive',
#  'Parks Avenue',
#  'Palm Drive',
#  'Grape Street',
#  'Santa Cruz Avenue',
#  '9th Street',
#  'Voltaire Street',
#  'Sundale Road',
#  'Camber Drive',
#  'Vista Coyote',
#  'Pine Street',
#  'Magdalene Way',
#  'Rhoda Drive',
#  'Hawk Street',
#  'B Street',
#  'Elden Avenue',
#  'Helix Street',
#  'Acacia Street',
#  'Carson Street',
#  'East 4th Street',
#  'Regulus Street',
#  'East 4th Street',
#  'Myrtle Beach Way',
#  'Vista Camino',
#  'Kite Street',
#  'Dante Street',
#  'Whitman Street',
#  'Cleveland Avenue',
#  'Daisy Avenue',
#  'Morocco Drive',
#  'Camino Calabazo',
#  'Mayita Way',
#  'Cowley Way',
#  'Kilkee Street',
#  'Calle Santiago',
#  'Rue Michelle',
#  'Crystal Drive',
#  'Emerald Street',
#  'Alpine Avenue',
#  'Angelus Avenue',
#  'Norstad Street',
#  'Germaine Lane',
#  'Carnegie Street',
#  'Bundy Drive',
#  'Park Terrace Drive',
#  'Greenfield Drive',
#  'Del Corro Court',
#  'Indigo Canyon Road',
#  'Stanford Avenue',
#  'Kenwood Drive',
#  'Honeysuckle Lane',
#  'Meadow Lark Drive',
#  '3rd Avenue',
#  'Beatrice Street',
#  'Hawk Street',
#  'Wateridge Vista Drive',
#  '11th Street',
#  'La Cuenta Drive',
#  'La Jolla Hermosa Avenue',
#  'Elm Avenue',
#  'Jefferson Avenue',
#  'East 8th Street',
#  'Donax Avenue',
#  'Bigford Street',
#  'Linen Drive',
#  'Catalina Boulevard',
#  'Gaylord Drive',
#  'Rawlins Way',
#  'West Naples Street',
#  'Parkside Drive',
#  'Brookview Lane',
#  '2nd Avenue',
#  'Malito Court',
#  'Chaparral Drive',
#  'Mary Court',
#  'Trailwood Avenue',
#  'Myrtle Avenue',
#  'Decker Street',
#  'Lincoln Avenue',
#  'Ocean Front Walk',
#  'East Lake Drive',
#  'Midvale Drive',
#  'Glen Canyon Circle',
#  'Chickasaw Court',
#  'Helen James Avenue',
#  'Dennison Street',
#  'Pony Lane',
#  'Mansfield Street',
#  'Alabama Street',
#  'Portsmouth Court',
#  'Glen Vista Way',
#  'Loren Drive',
#  'Frankfort Street',
#  'Dylan Street',
#  'Mayapan Drive',
#  'Chicago Drive',
#  'Melrose Street',
#  'Woodland Drive',
#  'Crawford Street',
#  'Birch Street',
#  'Jefferson Avenue',
#  'Fifield Street',
#  'Rue Michelle',
#  'Biola Avenue',
#  'Ray Street',
#  '48th Street',
#  'Twin Lake Drive',
#  'Torca Court',
#  'Greenfield Drive',
#  'Braidwood Street',
#  'Broadview Street',
#  'Via Escuda',
#  'Daisy Avenue',
#  'Pacifica Drive',
#  'Arguello Street',
#  'David Street',
#  'Joris Way',
#  'Menlo Avenue',
#  '48th Street',
#  'El Nopal',
#  'Woodside Avenue',
#  'B Avenue',
#  'Mission Gorge Road',
#  'Chollas Parkway',
#  'Settle Road',
#  'Flanders Drive',
#  'San Miguel Avenue',
#  'Lotus Street',
#  'Lemon Crest Drive',
#  'Monte Verde Drive',
#  'Flanders Drive',
#  'Campo Road',
#  'Edith Lane',
#  'East Madison Avenue',
#  'Cardiff Street',
#  'Mount Alifan Drive',
#  'Donald Avenue',
#  'Winona Avenue',
#  'Cherry Hills Lane',
#  'Willowgrove Avenue',
#  'Streamview Drive',
#  'Crosshaven Lane',
#  'Roosevelt Street',
#  'Concepcion Avenue',
#  'East Millan Street',
#  'Blackwood Drive',
#  'Palmetto Way',
#  'Fuerte Drive',
#  'Orange Street',
#  'Oliphant Street',
#  'C Street',
#  'Dragonfly Street',
#  'Ronda Avenue',
#  'Glebe Road',
#  'Whitney Street',
#  'Upas Street',
#  'Earl Street',
#  'Datcho Drive',
#  'Greenfield Drive',
#  'Deep Haven Lane',
#  'Haveteur Way',
#  'Weaver Street',
#  'Steiner Drive',
#  'Harwood Street',
#  'Montclair Street',
#  'El Monte Road',
#  'Baxter Street',
#  'Tommy Drive',
#  'Adams Avenue',
#  'Camulos Street',
#  '50th Street',
#  'Diamond Street',
#  'Palm Drive',
#  'Clanton Place',
#  'Wiggins Way',
#  'G Street',
#  'Mesa Terrace Road',
#  'Terraspiro Avenue',
#  'Vandever Avenue',
#  'University Avenue',
#  'Gage Drive',
#  'San Antonio Avenue',
#  'Cecelia Terrace',
#  'Hyatt Street',
#  'Skyline Drive',
#  'Morena Boulevard',
#  'Logan Avenue',
#  'Via Playa de Cortes',
#  'Barnhurst Drive',
#  '4th Avenue',
#  'Melrose Lane',
#  'South 2nd Street',
#  'Moonlight Trail Lane',
#  'Marline Avenue',
#  'Sapphire Street',
#  'East Lexington Avenue',
#  'Thunder Spring Drive',
#  'El Monte Road',
#  'Castaic Court',
#  'Cherokee Avenue',
#  'Buena Vista Way',
#  'Seminole Drive',
#  'West Point Loma Boulevard',
#  'Bass Street',
#  'Edgar Place',
#  'Roosevelt Street',
#  'Avenida Ysidora',
#  'Railroad Avenue',
#  'Saratoga Avenue',
#  'K Street',
#  'Irvington Avenue',
#  'Arillo Street',
#  'Petit Street',
#  'Paseo Burga',
#  'Olive Avenue',
#  'Adams Avenue',
#  'Beryl Street',
#  'Lago Madero',
#  'Mount Owen Court',
#  'Wilson Avenue',
#  'Vista Way',
#  'Delta Street',
#  'Alpha Street',
#  'Leticia Drive',
#  'Collingwood Drive',
#  'Agua Vista Way',
#  'Fig Avenue',
#  'Trade Street',
#  'Pilot Way',
#  'Encino Row',
#  'Elm Avenue',
#  'Rancho Court',
#  'Calle Trucksess',
#  'Larga Circle',
#  'Robbins Street',
#  'Elm Avenue',
#  'Carmichael Drive',
#  'Paseo del Cerro',
#  'Bluehaven Court',
#  'Golfcrest Drive',
#  'Larch Street',
#  'Norran Avenue',
#  'Gribble Street',
#  'Mesita Drive',
#  'West 15th Street',
#  'Del Coronado Lane',
#  'Streamview Drive',
#  'Roanoke Street',
#  'Alumni Place',
#  'Azure Coast Drive',
#  'Syracuse Avenue',
#  'Brighton Avenue',
#  'Middlesex Drive',
#  '30th Street',
#  'Barbic Court',
#  'Channel Road',
#  'Torrey Pines Road',
#  'Palawan Way',
#  'Plaza Cuernavaca',
#  'Billow Drive',
#  'Manzanita Street',
#  'Johnson Drive',
#  'Sunny View Drive',
#  'Seascape Drive',
#  'Orchard Avenue',
#  'Winter Gardens Boulevard',
#  '5th Avenue',
#  'Lagrange Road',
#  'Layla Way',
#  'Ravenrock Court',
#  'Mary Lane Drive',
#  'Jellett Street',
#  'Via Granero',
#  'West Pennsylvania Avenue',
#  'Marbella Court',
#  'Coldwell Lane',
#  'Sweetwood Street',
#  'Voltaire Street',
#  'J Street',
#  'Frisbie Street',
#  'Ridgecliff Lane',
#  'Hatteras Avenue',
#  '58th Street',
#  'Hancock Street',
#  'Valencia Place',
#  'Logan Avenue',
#  'Kellogg Street',
#  'Aster Street',
#  'Glenwood Drive',
#  'Positas Road',
#  'Plumbago Lane',
#  'Citrus Avenue',
#  'Arnold Avenue',
#  'Lakeside Avenue',
#  'Caminito Agrado',
#  'Muirlands Drive',
#  'Constellation Drive',
#  'Avocado Avenue',
#  'Ronda Avenue',
#  'Plaza Miraleste',
#  'Harbison Place',
#  'Convoy Street',
#  'Via Arcilla',
#  'Altadena Avenue',
#  'F Street',
#  'Pabellon Circle',
#  'Corte Maria Avenue',
#  'Lincoln Street',
#  'Melody Lane',
#  'Jamacha Road',
#  'Lindbergh Street',
#  '73rd Street',
#  'Hemlock Avenue',
#  'Caminito Abeto',
#  'Clairemont Drive',
#  'Olive Drive',
#  'South 40th Street',
#  'Willamette Avenue',
#  'Vista Way',
#  'West 35th Street',
#  'F Street',
#  'Emory Street',
#  'Valencia Street',
#  'Tarragona Drive',
#  'Liberty Creek Place',
#  'Pershing Avenue',
#  'Florida Street',
#  'Caminito Pudregal',
#  'Guymon Street',
#  'Casa Place',
#  'Maryland Avenue',
#  'Swift Avenue',
#  'Easthaven Court',
#  'Chardonnay Terrace',
#  'Frankfort Street',
#  'Baldwin Road',
#  'Eastridge Drive',
#  'Alpine Avenue',
#  'Troy Street',
#  'Dahlia Avenue',
#  'Horner Street',
#  '48th Street',
#  'Robinhood Lane',
#  'Innsdale Lane',
#  'Winnett Street',
#  'Pearlwood Street',
#  'Ridgecrest Drive',
#  'Avenida Marcella',
#  'J Avenue',
#  'Portsmouth Court',
#  'Hacienda Drive',
#  'Helen James Avenue',
#  'Nye Street',
#  'Palmetto Way',
#  'Superior Street',
#  'South Lake Court',
#  'Alveda Avenue',
#  'Caminito Cachorro',
#  'Juanita Street',
#  'West Chase Avenue',
#  'Midland Street',
#  'Baffin Drive',
#  'Volclay Drive',
#  'Ridgecrest Drive',
#  'Saratoga Avenue',
#  'Sparrow Street',
#  'Glen Road',
#  'Frankfort Street',
#  'Gustine Street',
#  'Dassco Court',
#  'Bonair Street',
#  'Beaver Lake Drive',
#  'Ada Street',
#  'Oliver Avenue',
#  'Udall Street',
#  'Sheldon Drive',
#  'Finch Lane',
#  'Epsilon Street',
#  'Hansel Drive',
#  'Arruza Street',
#  'Broadway',
#  '38th Street',
#  'East 2nd Street',
#  'Catalina Boulevard',
#  'Apache Drive',
#  'Wayne Avenue',
#  'Swift Avenue',
#  '6th Avenue',
#  'Lalani Drive',
#  'Jessie Avenue',
#  'New Mills Road',
#  'Rochdale Lane',
#  'Porch Swing Street',
#  'Woodside Avenue',
#  'Huggins Street',
#  'Ridgeview Way',
#  'Salem Court',
#  'Melrose Avenue',
#  'Settle Road',
#  'Jamul Avenue',
#  'Merritt Boulevard',
#  'Bridgetown Bend',
#  'East Olympia Street',
#  'Mission Avenue',
#  'Montclair Street',
#  'Central Avenue',
#  '5th Avenue',
#  'Dupont Drive',
#  'Cabrillo Avenue',
#  'Roseland Drive',
#  'Oconnor Avenue',
#  'Farmdale Street',
#  '54th Street',
#  'Valva Avenue',
#  'Bernadine Place',
#  'Orchard Avenue',
#  'Howard Avenue',
#  'Rondel Court',
#  'Eads Avenue',
#  '30th Street',
#  'Polk Avenue',
#  'Loring Street',
#  'Palomar Avenue',
#  'Streamview Drive',
#  'University Avenue',
#  'Antoine Drive',
#  'North Cuyamaca Street',
#  'L Avenue',
#  'Coconut Lane',
#  'Biltmore Street',
#  '21st Street',
#  'Redcrest Drive',
#  'I Avenue',
#  'Doubletree Road',
#  'Shasta Street',
#  'Roman Way',
#  'Bonsall Street',
#  'Bedfont Circle',
#  'Bonita Verde Drive',
#  'Olive Avenue',
#  'Fairbrook Road',
#  'Subol Court',
#  'Lake Atlin Avenue',
#  'Werner Street',
#  'Carnell Avenue',
#  'Archer Street',
#  'Clayford Street',
#  'Rancho Drive',
#  'Ariane Way',
#  'Marjorie Drive',
#  'Buckskin Road',
#  'Main Street',
#  'Amoroso Street',
#  'South Hempstead Circle',
#  'Mariner Drive',
#  'Stone Court',
#  'Roselle Avenue',
#  '55th Street',
#  'Cliffridge Avenue',
#  'Clear Sky Road',
#  'El Cajon Boulevard',
#  'Caminito Mira',
#  'Carlton Hills Boulevard',
#  'Forest Oaks Drive',
#  'Arthur Neal Court',
#  'San Remo Court',
#  'Herman Avenue',
#  'Connell Road',
#  'Washington Street',
#  'Dale Street',
#  'Dahlia Avenue',
#  'Pavlov Avenue',
#  'Cypress Avenue',
#  'Bannister Way',
#  'Pearson Springs Court',
#  'Glover Avenue',
#  'Division Street',
#  'Point Loma Avenue',
#  'Home Avenue',
#  'Logan Avenue',
#  'Santa Barbara Street',
#  'King Street',
#  '34th Street',
#  'Chaumont Drive',
#  'Vista del Sur',
#  'Ilex Avenue',
#  'Paradise Street',
#  'Bellevue Avenue',
#  'Glover Place',
#  'Edge Park Way',
#  'Sandpiper Strand',
#  'Taos Drive',
#  'Madrid Way',
#  'G Street',
#  'Lisieux Terrace',
#  'Escondido Avenue',
#  '48th Street',
#  'Satinwood Way',
#  'Pebble Beach Drive',
#  'Alderbrook Place',
#  '59th Street',
#  '45th Street',
#  'San Diego Mission Road',
#  'Thomas Avenue',
#  'Dalehurst Road',
#  'Sea Reef Drive',
#  'Lupin Way',
#  'El Rancho Vista',
#  'Red Oak Place',
#  'Mission Gorge Road',
#  'Barbarossa Drive',
#  'Sparks Avenue',
#  'Oleander Drive',
#  'Via de Amor',
#  'Wagon Wheel Court',
#  'Howard Avenue',
#  'Caminito Rogelio',
#  'Alder Street',
#  'East Overlook Drive',
#  'Los Altos Court',
#  'Montessa Street',
#  'Roy Street',
#  'Otay Valley Road',
#  'East Talmadge Drive',
#  'Plaza Toluca',
#  'Red Granite Road',
#  'Pacific Highway',
#  'Massasoit Avenue',
#  'Elder Avenue',
#  'Carmel Avenue',
#  'Mount Ariane Drive',
#  'O Avenue',
#  'Bancroft Drive',
#  'Rhoades Court',
#  'Gate Five Place',
#  'East 16th Street',
#  'Banneker Drive',
#  'Cape May Avenue',
#  'Australia Street',
#  'Sunnyside Avenue',
#  'Belle Glade Avenue',
#  '3rd Avenue',
#  'Washington Street',
#  'Garber Avenue',
#  'Deaton Drive',
#  '15th Street',
#  'Paraiso Avenue',
#  'Elm Avenue',
#  'Honors Drive',
#  'Rosemont Street',
#  'Golf Glen Road',
#  'Camino Largo',
#  'Travers Way',
#  'Marigold Place',
#  'West Talmadge Drive',
#  'Cohasset Court',
#  'Murray Drive',
#  'Broadrick Way',
#  'Shoreacres Drive',
#  'Sequoia Street',
#  'Lodi Street',
#  'Wandermere Drive',
#  'Volclay Drive',
#  'Amada Place',
#  'Mocking Bird Drive',
#  'Chase Lane',
#  'Joshua Creek Road',
#  'Rumson Drive',
#  '12th Street',
#  'Corte Playa Madera',
#  'Parkway Drive',
#  'Wind River Road',
#  'Phoenix Drive',
#  'Milden Street',
#  'F Street',
#  'Pequena Street',
#  'Shasta Street',
#  'Olvera Avenue',
#  'Red Rock Court',
#  'Morning Star Drive',
#  'Long Lake Court',
#  'Megan Way',
#  '5th Avenue',
#  'Fairhill Terrace',
#  'Valencia Parkway',
#  'Mission Gorge Road',
#  'Pacific Beach Drive',
#  'Forbes Avenue',
#  'Railroad Avenue',
#  'Century Street',
#  'Park Way',
#  'K Street',
#  'Robin Place',
#  'Rose Street',
#  'Old Janal Ranch Road',
#  'Osage Street',
#  'Monroe Avenue',
#  'Long Branch Avenue',
#  'Martinez Street',
#  'Normandie Place',
#  'Gotham Street',
#  'Harvard Street',
#  'Golondrina Drive',
#  'Bertro Drive',
#  'Plaza Palo Alto',
#  '43rd Street',
#  'Curlew Street',
#  'Norte Mesa Drive',
#  'Shy Lane',
#  'Shenandoah Drive',
#  'Harjoan Avenue',
#  'Alleghany Street',
#  'Van Houten Avenue',
#  'Hawaii Avenue',
#  'Alta View Drive',
#  'Sherbrooke Street',
#  'Valle Vista Road',
#  'Winlow Street',
#  'Orozco Road',
#  'Lyle Drive',
#  'Eagle Rock Avenue',
#  'Purdue Avenue',
#  'Caminito Espino',
#  'Alta Drive',
#  'Mile of Cars Way',
#  'Ronald Court',
#  'Hemlock Avenue',
#  'University Avenue',
#  'Mars Way',
#  'Lake Ariana Avenue',
#  'Liebel Court',
#  'Mount Putman Avenue',
#  'Industrial Boulevard',
#  'Roselle Avenue',
#  'Mary Lou Street',
#  'Froude Street',
#  'Normandie Place',
#  'Santa Cruz Avenue',
#  'Savannah Court',
#  'Eucalyptus Street',
#  'Schaumberg Place',
#  'Montcliff Road',
#  'Roe Drive',
#  'Jamacha Road',
#  'Feather Avenue',
#  'Ivy Street',
#  'North R Avenue',
#  'Broadway',
#  'Trias Street',
#  'Summit Ridge Way',
#  'Mission Boulevard',
#  'Grove Road',
#  'Huerfano Avenue',
#  'Jackson Hill Lane',
#  'Ferguson Way',
#  'Nilo Way',
#  '19th Street',
#  'Old Oak Drive',
#  'Irvington Avenue',
#  'Adella Avenue',
#  '1st Avenue',
#  'Carly Court',
#  'Rodrigo Drive',
#  'Vivaracho Way',
#  'Old Bridgeport Way',
#  'Spruce Street',
#  'Wild Oak Road',
#  'North Cordoba Avenue',
#  'Parkwood Drive',
#  'Mount Ariane Drive',
#  'Sunrise Bluff Drive',
#  'Klamath Drive',
#  'I Street',
#  'Falconfire Way',
#  'Via Suspiro',
#  'Twain Avenue',
#  'Jaynia Place',
#  'Navello Street',
#  'Cedar Springs Drive',
#  'Wild Oats Lane',
#  'Farnham Street',
#  'La Morada Drive',
#  'Hansom Lane',
#  'Graves Avenue',
#  'Redwood Street',
#  'Via Miraleste',
#  'Pine Street',
#  'Tremaine Way',
#  'South Granada Avenue',
#  'Central Avenue',
#  'East Quintard Street',
#  'Washington Street',
#  'Beaumont Avenue',
#  'Balboa Avenue',
#  'Potomac Street',
#  'Barkla Street',
#  'El Cerrito Place',
#  'Acuff Drive',
#  'Medford Street',
#  'Avenida Antonio',
#  'Zola Street',
#  'Tremont Street',
#  'Canyon Lake Drive',
#  'Enero Street',
#  'Polk Avenue',
#  'Adelaide Avenue',
#  'Skyview Street',
#  'Cynthia Place',
#  'Lake Badin Avenue',
#  'Emerald Cove',
#  'Taft Avenue',
#  'Almayo Court',
#  'Lairwood Drive',
#  'Thelborn Way',
#  'Lotus Drive',
#  'Sheffield Court',
#  'Vista Street',
#  'Canton Drive',
#  'Valencia Street',
#  'Imperial Beach Boulevard',
#  'J Avenue',
#  'Indiana Street',
#  'The Inlet',
#  'Encina Drive',
#  'Vernette Drive',
#  'Osler Street',
#  'Duncan Ranch Road',
#  'Loring Street',
#  'Seaman Street',
#  'Del Rio Road',
#  'Turquoise Street',
#  'Bluehaven Court',
#  'Sherwood Drive',
#  'Vista Place',
#  'Webster Avenue',
#  'Tommy Drive',
#  'Opal Street',
#  '12th Street',
#  'Jefferson Avenue',
#  'West 17th Street',
# ...
#  'Rippey Street',
#  'Wild Oats Lane',
#  'Sunset Cliffs Boulevard',
#  'Hidden Valley Avenue',
#  'Rancho Fanita Drive',
#  'Amarillo Avenue',
#  'Corkwood Avenue',
#  'Adella Avenue',
#  'Rodman Avenue',
#  'May Avenue',
#  'Deerpark Drive',
#  'South Orange Avenue',
#  'Avenida Cresta',
#  'Grandview Place',
#  'Caulfield Drive',
#  'Old Ranch Road',
#  'Lotus Drive',
#  'Carancho Street',
#  'Peach Avenue',
#  'Margerum Avenue',
#  'Old Bridgeport Way',
#  'Monserate Avenue',
#  'Crestview Drive',
#  'Commerce Avenue',
#  'Queen Anne Drive',
#  'Gardena Road',
#  'Calle Camille',
#  'Lisbon Street',
#  'Date Avenue',
#  'East Hartland Circle',
#  'Avenida de la Cruz',
#  'Art Street',
#  'Long Branch Avenue',
#  'Creekford Drive',
#  'Mesa Park Lane',
#  'Nexus Centre Drive',
#  '32nd Street',
#  'Madera Rosa Way',
#  'Baily Avenue',
#  'Ocean View Boulevard',
#  'Marl Avenue',
#  'Sunnyside Avenue',
#  'Beck Drive',
#  'Union Street',
#  'East 31st Street',
#  'Shutter Court',
#  'The Point',
#  '67th Street',
#  'La Junta Avenue',
#  'Carmenita Road',
#  'Lemon Avenue',
#  'Arroyo Seco Drive',
#  'Madera Street',
#  'Lionel Street',
#  'Lakeside Avenue',
#  'Marline Avenue',
#  'Fletcher Parkway',
#  'East 3rd Street',
#  'Chicago Street',
#  'Mc Kinley Street',
#  'Swift Avenue',
#  'Jones Street',
#  'Del Paso Avenue',
#  'Gatewood Lane',
#  'Willow Terrace',
#  '30th Street',
#  'Waterside Drive',
#  'Handrich Drive',
#  'Mendocino Boulevard',
#  'North Kenton Avenue',
#  'Surfwood Lane',
#  'West Beech Street',
#  'Carleton Street',
#  'Hunters Pointe Avenue',
#  'Vista Santa Rosalia',
#  'Wheatlands Court',
#  'Summit Drive',
#  'Beta Street',
#  'Corte San Simeon',
#  'Olivewood Terrace',
#  'Waring Road',
#  'Washington Street',
#  'Wabash Avenue',
#  'Wolfsdorf Way',
#  'Alta View Drive',
#  'Avanti Avenue',
#  'Sweetwater Road',
#  'West 18th Street',
#  'Loma Lane',
#  'Verin Lane',
#  'Helix Street',
#  'Albemarle Street',
#  'Isleworth Avenue',
#  'Broadview Street',
#  'South Cordoba Avenue',
#  'Sea Robin Court',
#  'Buena Vista Avenue',
#  'Calle Serena',
#  'Pepper Drive',
#  'Lorna Avenue',
#  'Coach Drive',
#  'Monserate Avenue',
#  'Pine Grove Street',
#  'Timberlane Way',
#  'Guy Street',
#  'Oak Place',
#  'Guatay Avenue',
#  'Rio San Diego Drive',
#  'Topaz Lake Avenue',
#  'Burgundy Street',
#  'Carbine Way',
#  'Bayonne Drive',
#  'Curtis Street',
#  '9th Street',
#  'Paisley Street',
#  'Gotham Street',
#  'Rancho Drive',
#  'Parkway Drive',
#  'Imperial Avenue',
#  'Donax Avenue',
#  'Michelle Court',
#  'Summit Avenue',
#  '73rd Street',
#  'Theresa Way',
#  'Grosalia Avenue',
#  'Redwood Street',
#  'Lomker Way',
#  'Mast Boulevard',
#  'Butternut Hollow Lane',
#  'Calle de Vida',
#  'Meeks Bay Drive',
#  '52nd Street',
#  'Elder Avenue',
#  'Alejo Street',
#  'Pacific Beach Drive',
#  'Walsh Way',
#  '8th Street',
#  'East Oxford Street',
#  'Bonita Road',
#  'C Street',
#  'Columbia Street',
#  '35th Street',
#  'G Avenue',
#  'Via Kenora',
#  'Delta Street',
#  'Helix View Drive',
#  'Dubois Drive',
#  'Wightman Street',
#  'Cherry Blossom Street',
#  'Roanoke Street',
#  'Outinda Street',
#  'Oak Creek Drive',
#  'Merrimac Avenue',
#  'Ralph Way',
#  '54th Street',
#  'Ohio Street',
#  'Jackson Drive',
#  'Marcilla Way',
#  'Casselberry Way',
#  'Strawberry Lane',
#  'Steel Street',
#  'La Mesa Boulevard',
#  'Kempton Street',
#  'Altadena Road',
#  'Saddleview Court',
#  'Palomar Street',
#  'Castle Court Drive',
#  'L Street',
#  'Dante Street',
#  'Helix Street',
#  'Jasper Court',
#  'Madison Avenue',
#  'Kimberly Drive',
#  'Whinchat Street',
#  'Terra Nova Drive',
#  'East 3rd Street',
#  'Emerald Grove Avenue',
#  '20th Street',
#  'Bullock Drive',
#  'Carlsbad Street',
#  'Fulton Street',
#  'Isom Court',
#  'El Cajon Boulevard',
#  'Gold Coast Drive',
#  'Horton Drive',
#  'Bernice Drive',
#  'Rumson Drive',
#  'Pierre Way',
#  'California Street',
#  'Yonge Street',
#  'Redcrest Place',
#  'Gorsline Drive',
#  'Esmeraldas Drive',
#  'Sea Reef Place',
#  'Burgener Boulevard',
#  'Ballantyne Street',
#  'O Avenue',
#  'Redwood Street',
#  'H Avenue',
#  'Adella Avenue',
#  'North Pierce Street',
#  'Solola Avenue',
#  'Dove Street',
#  'Brant Street',
#  'Manzana Way',
#  'Wilson Avenue',
#  'Fieldbrook Street',
#  'Cabernet Way',
#  'Casa Blanca Place',
#  'Allenhurst Place',
#  'Elmhurst Street',
#  'Milburn Avenue',
#  'Holborn Court',
#  'South Ivory Avenue',
#  'Hidden Valley Avenue',
#  'Trenton Avenue',
#  'Oasis Avenue',
#  'East Falls View Drive',
#  'Guatay Avenue',
#  'Blue Ridge Court',
#  'Ray Street',
#  'Green Street',
#  'Pergl Street',
#  'Moraga Avenue',
#  'La Cruz Drive',
#  'Camino del Rey',
#  'Quinn Court',
#  'Trinidad Way',
#  'Calavo Drive',
#  'Corral Canyon Road',
#  'Wilson Avenue',
#  'South Magnolia Avenue',
#  'Battle Creek Road',
#  'Fay Avenue',
#  'Crystal Springs Drive',
#  'Inverness Road',
#  'Everglades Avenue',
#  'Rancho Park Drive',
#  'Emerald Grove Avenue',
#  'Sparrow Lake Road',
#  'Mount Armet Drive',
#  'Tuther Way',
#  'Norstad Street',
#  'Cristobal Drive',
#  '70th Street',
#  'Bancroft Street',
#  'Avenida de Las Pescas',
#  'La Paz Drive',
#  'Hill Street',
#  'Irvington Avenue',
#  'North Talmadge Drive',
#  'Acacia Street',
#  'Hebrides Drive',
#  'Key Lane',
#  'Coronado Avenue',
#  'Dubois Drive',
#  'Pacific Highway',
#  'Van Dyke Avenue',
#  'Judson Street',
#  'Valemont Street',
#  'San Pasqual Court',
#  'Valkyria Lane',
#  'Irwin Street',
#  'West Ivy Street',
#  'Orange Street',
#  'Crystal Clear Drive',
#  'East 19th Street',
#  'Seagreen Place',
#  '3rd Avenue',
#  'Meeks Bay Drive',
#  'Felton Street',
#  'Star Magnolia Lane',
#  'Winter View Court',
#  'Rocking Horse Drive',
#  'Goldfield Street',
#  'Curtis Street',
#  'National Avenue',
#  'La Posada Street',
#  'Kline Street',
#  'Riverlawn Avenue',
#  'Honeycutt Street',
#  'Palomar Avenue',
#  'Little Leaf Lane',
#  'Gold Coast Drive',
#  'Middle Fork Place',
#  'Fenelon Street',
#  'Broadway',
#  'Vallejo Mills Street',
#  'Dennison Street',
#  'Carolyn Drive',
#  'Midway Drive',
#  'Diamondback Drive',
#  'Hightree Lane',
#  'East Mountain View Drive',
#  'Mesita Drive',
#  'Berwick Drive',
#  'Gesner Street',
#  'Dorothy Street',
#  'Minot Avenue',
#  'Brookhurst Avenue',
#  'Commercial Street',
#  'Pennsylvania Avenue',
#  '52nd Street',
#  'Viacha Drive',
#  'Delta Street',
#  'National Avenue',
#  'Sima Court',
#  'Mission Boulevard',
#  'Royal Road',
#  'Golden Gate Avenue',
#  'Energy Way',
#  'Skyline Drive',
#  'Upshur Street',
#  'Chalcedony Street',
#  'North 2nd Street',
#  'Onondaga Avenue',
#  'K Street',
#  'Sierra Way',
#  'Prospect Street',
#  'Flora Verda Court',
#  'Eldora Street',
#  'Skyline Drive',
#  'Gowdy Avenue',
#  'Tokalon Street',
#  'Brown Drive',
#  'Tulane Street',
#  'Kincaid Avenue',
#  'Raven Street',
#  'Rocoso Road',
#  'Grossmont Avenue',
#  'Bentley Drive',
#  'Trias Street',
#  'Loukelton Way',
#  'Blackton Drive',
#  'Tobey Street',
#  'Esther Street',
#  'Conifer Avenue',
#  'Debenmark Place',
#  'Collier Avenue',
#  'Saint Rita Court',
#  'Carreta Drive',
#  'North Cordoba Avenue',
#  'Escobar Drive',
#  'Pheasant Drive',
#  'Clairemont Drive',
#  'Highgate Lane',
#  'Wilson Avenue',
#  'Cedral Place',
#  'South Granada Avenue',
#  'Ava Street',
#  'Arinjade Way',
#  'Morning Creek Road',
#  'East Lexington Avenue',
#  'Mollie Lane',
#  'Byron Street',
#  'Virginia Way',
#  '68th Street',
#  'Lawndale Street',
#  'Idlewild Way',
#  'Russell Street',
#  'Ariane Drive',
#  'Venice Street',
#  'Kaanapali Way',
#  'Wing Street',
#  'Coronado Avenue',
#  'Alber Street',
#  'Cypress Avenue',
#  'Kostner Drive',
#  'Via Diego Terrace',
#  'Pine Grove Street',
#  'La Morada Drive',
#  'Wightman Street',
#  'Glidden Lane',
#  'Arborcreek Lane',
#  'East Lane',
#  'Nile Street',
#  'Mount Abbey Avenue',
#  'Worden Street',
#  'Dancy Court',
#  'Rancho Drive',
#  'South Siena Street',
#  'Byron Street',
#  'Roberts Drive',
#  'Wunderlin Avenue',
#  'Goodman Lane',
#  'Robinson Place',
#  'South Harbison Avenue',
#  'Capehart Street',
#  'Sesame Street',
#  'Oaklawn Avenue',
#  'San Miguel Drive',
#  'San Vicente Street',
#  'Wheatville Street',
#  'Pepper Drive',
#  'Limerick Avenue',
#  '50th Street',
#  'Olivetas Avenue',
#  'South Vista Avenue',
#  'J Avenue',
#  'Otis Court',
#  'Millwood Road',
#  'Bunnell Street',
#  'Alta Drive',
#  'South Anza Street',
#  'Casa Bonita Court',
#  'Troy Street',
#  'Rosemont Street',
#  'Hamilton Street',
#  'Simi Place',
#  'Del Monte Avenue',
#  'Galaxy Court',
#  'Hudson Drive',
#  'Broadway',
#  'Palin Street',
#  'Corte Escena',
#  'Robinhood Lane',
#  'Carroll Way',
#  'F Street',
#  'Oriole Street',
#  'La Corta Circle',
#  'Rocoso Road',
#  'Oakleaf Point',
#  'Calumet Avenue',
#  'Elkelton Boulevard',
#  'D Avenue',
#  'Lakewood Street',
#  'Blue Lake Drive',
#  'Vista Santa Rita',
#  'Ada Street',
#  'Fleming Drive',
#  'Echo Ridge Terrace',
#  'Crescent Drive',
#  'Charro Court',
#  'Princess Joann Road',
#  'Fortuna Street',
#  'Malorey Street',
#  'Calle Leticia',
#  'Newport Avenue',
#  'Boca Raton Drive',
#  'Felspar Street',
#  'University Avenue',
#  'Red Rock Canyon Road',
#  'Sheffield Court',
#  'Luna Avenue',
#  'Juniper Street',
#  'Felton Street',
#  'Myrtle Avenue',
#  'Park Drive',
#  'Trigal Way',
#  'Mount Albertine Avenue',
#  'McHaney Court',
#  'Cullen Street',
#  'Quintard Street',
#  'Vista del Oro Way',
#  'Roseland Drive',
#  'Paseo Entrada',
#  'Nile Avenue',
#  'Diane Avenue',
#  'Elm Avenue',
#  'Wilts Place',
#  'Three Oaks Way',
#  'Canton Drive',
#  'Old Janal Ranch Road',
#  'Oregon Street',
#  'Valle Vista Road',
#  '3rd Avenue',
#  'Redwood Street',
#  'Palm Avenue',
#  'Tres Lagos Court',
#  'Santa Cruz Avenue',
#  'Malcolm Drive',
#  'Old Grove Road',
#  'Single Oak Drive',
#  'Brems Street',
#  'Vancouver Avenue',
#  'Arnold Avenue',
#  'Georgia Street',
#  'Trinidad Way',
#  'Lincoln Court',
#  '35th Street',
#  'Calle Tiara',
#  'Enfield Street',
#  'Market Street',
#  'Minnesota Avenue',
#  'Valle Avenue',
#  'Zephyr Avenue',
#  'El Cajon Boulevard',
#  'Picket Fence Drive',
#  'Auburn Drive',
#  'Sherwin Place',
#  'Commercial Street',
#  'Notre Dame Avenue',
#  'Conrad Avenue',
#  'Birchcrest Boulevard',
#  'Keen Drive',
#  'College Avenue',
#  'Madra Avenue',
#  'Palm Row Drive',
#  'Hughes Court',
#  'Biola Avenue',
#  'College Avenue',
#  'Derald Road',
#  'North del Mar Avenue',
#  'Dorado Way',
#  'Lake Ariana Avenue',
#  '33rd Street',
#  'Via Carolina',
#  '6th Avenue',
#  'Pala Street',
#  'Via Felicia',
#  'East Renette Avenue',
#  'Brandywood Street',
#  'Mount Albertine Avenue',
#  'Ramsay Avenue',
#  'Hillcreek Lane',
#  '34th Street',
#  'Naples Street',
#  'Caminito Halago',
#  'Evilo Street',
#  'Orange Avenue',
#  'El Cajon Boulevard',
#  '2nd Avenue',
#  'Ian Way',
#  'Sandstone Drive',
#  '47th Street',
#  'Perth Place',
#  'Caminito Estrellado',
#  'Julian Avenue',
#  'Hartford Street',
#  'New Haven Road',
#  'Angelus Avenue',
#  'C Avenue',
#  'Lipmann Street',
#  'Coe Place',
#  'Bevis Street',
#  'Avocado Boulevard',
#  'Los Reyes Drive',
#  'Edgemont Street',
#  'East Park Avenue',
#  'Manzanita Road',
#  'Law Street',
#  'Blackwood Road',
#  'Dutton Drive',
#  'Winona Avenue',
#  'Mount Everest Boulevard',
#  'Brighton Court',
#  'Pershing Avenue',
#  'Castellana Road',
#  'Voltaire Street',
#  'Paseo Los Gatos',
#  '54th Street',
#  'Madrid Street',
#  'Walton Place',
#  'Melody Lane',
#  'Barneveld Street',
#  'Grosalia Avenue',
#  '10th Avenue',
#  'Nipoma Street',
#  'Van Houten Avenue',
#  'Terrace Drive',
#  'Albatross Street',
#  'East 7th Street',
#  'Coronado Avenue',
#  'Manzana Way',
#  'South Gregory Street',
#  'Laffey Lane',
#  'Cervantes Avenue',
#  'Amber Lake Avenue',
#  'Lake Mere Court',
#  'Lockwood Drive',
#  'Alvarado Street',
#  'Canton Drive',
#  'Lesa Road',
#  'Larga Circle',
#  'Henry Lane',
#  'Gardena Avenue',
#  'Elm Avenue',
#  '3rd Street',
#  'Forest Oaks Drive',
#  '31st Street',
#  'Lechuza Lane',
#  'Lemon Avenue',
#  'Plaza Mar',
#  'Reo Drive',
#  'Ada Street',
#  'Calle del Amor',
#  'Madison Avenue',
#  'Feather Avenue',
#  'Playa del Norte',
#  'Isham Springs Court',
#  'Saint George Place',
#  'Laird Street',
#  'Harris Street',
#  'Monte Verde Drive',
#  'Monroe Avenue',
#  'Sampson Street',
#  'Clara Lee Avenue',
#  'Big Cone Drive',
#  'Vista del Mar Avenue',
#  'Lamar Street',
#  'Via Capri',
#  'Ilex Avenue',
#  'Fino Drive',
#  'Woodlawn Avenue',
#  'Sugarman Drive',
#  'Kemerton Road',
#  '66th Street',
#  'Missouri Street',
#  'Janet Lane',
#  'Raedel Drive',
#  'Prospect Avenue',
#  'Pennywood Road',
#  'Bonita Glen Terrace',
#  'Via Bartolo',
#  'Winter Gardens Boulevard',
#  '28th Street',
#  'Wilson Avenue',
#  'Pepper Drive',
#  'San Miguel Drive',
#  '33rd Street',
#  'Broadway',
#  'Hillside Drive',
#  'Chicago Street',
#  'Oakdale Avenue',
#  'Nomel Lane',
#  '7th Street',
#  'Cardiff Street',
#  'Newport Avenue',
#  '5th Street',
#  'Treehouse Street',
#  'Toyne Street',
#  'Hugo Street',
#  'Ozzie Way',
#  'Paseo Sarina',
#  'E Street',
#  'Sioux Avenue',
#  'Winter Gardens Drive',
#  'Abraham Way',
#  'Watwood Road',
#  'Meade Avenue',
#  'Princeton Avenue',
#  'Rolando Knolls Drive',
#  'Chandler Drive',
#  '38th Street',
#  'Lantana Drive',
#  'Bandini Street',
#  'McCloud River Road',
#  'Deerpark Drive',
#  'Broadway',
#  'Crela Street',
#  'Melrose Avenue',
#  'Syracuse Way',
#  'Balboa Vista Drive',
#  'Summerwood Lane',
#  'Prospect Place',
#  'East Renette Avenue',
#  'Murphy Canyon Road',
#  'Clayford Street',
#  'Plaza Kadie',
#  'Grandview Drive',
#  'Mandan Way',
#  'Nimitz Boulevard',
#  'Coldwell Lane',
#  'Omeara Street',
#  '54th Street',
#  'Anja Place',
#  '46th Street',
#  'Caminito Pintoresco',
#  'Gibson Street',
#  'Amino Drive',
#  'Rolando Boulevard',
#  'Paradise Valley Road',
#  'Palm Avenue',
#  'Via Hacienda',
#  'Paradise Street',
#  'Monitor Road',
#  'El Cajon Boulevard',
#  'Prospect Street',
#  'West Renette Avenue',
#  'Winchester Street',
#  'Brockway Street',
#  '24th Street',
#  'Innuit Avenue',
#  'Madrid Way',
#  '69th Street',
#  'University Avenue',
#  'Hunthaven Road',
#  'Drew View Lane',
#  'Tonto Way',
#  'Georgia Street',
#  'Rollsreach Drive',
#  'Bryanview Circle',
#  'Honors Drive',
#  'Huron Avenue',
#  'Cole Street',
#  'View Park Way',
#  'Guincho Road',
#  'North Cordoba Avenue',
#  'Brando Drive',
#  'Waverly Avenue',
#  'East 16th Street',
#  'Curtis Street',
#  'Alameda Terrace',
#  'Golden Avenue',
#  'Cartulina Road',
#  'Tweed Street',
#  'Lake Country Drive',
#  'Bellevue Avenue',
#  'Bonnie View Drive',
#  'Connoley Avenue',
#  'Moraga Place',
#  'Cooper Street',
#  'East Douglas Avenue',
#  'Millwood Road',
#  '5th Avenue',
#  'Calle Pavana',
#  'Dwight Street',
#  '3rd Avenue',
#  'Teebird Lane',
#  '56th Street',
#  'Centre Street',
#  'El Monte Road',
#  'Diversion Drive',
#  'Florida Street',
#  'Jumano Avenue',
#  'L Street',
#  '51st Street',
#  'San Diego Street',
#  'Tobias Drive',
#  'Morena Boulevard',
#  'Cottonwood Street',
#  'Mount Ariane Drive',
#  'Tanoak Court',
#  'Valencia Loop',
#  'Calumet Avenue',
#  'Artemia Way',
#  'Peacock Valley Road',
#  '47th Street',
#  'Camino de Las Palmas',
#  'Wateridge Circle',
#  'North Mollison Avenue',
#  'Par Drive',
#  'Esmeraldas Drive',
#  'La Donna Lane',
#  'Westmorland Street',
#  'East Washington Avenue',
#  'Elkwood Avenue',
#  '49th Street',
#  'Pacific Highway',
#  'Mount Ainsworth Avenue',
#  'Caminito Silvela',
#  'Grand Avenue',
#  'East Harbor Drive',
#  'Windmill View Road',
#  'Abuela Drive',
#  'Mount Abernathy Avenue',
#  'Lazy Clouds Point',
#  'Celia Vista Drive',
#  'Cohasset Court',
#  'Caminito Agrado',
#  'Lenore Drive',
#  'Ronson Road',
#  'Halifax Street',
#  'Savage Court',
#  'Hacienda Drive',
#  'Challenger Circle',
#  'Vermont Street',
#  'Rue Cheaumont',
#  'Oaklawn Avenue',
#  'Idaho Street',
#  'Akins Avenue',
#  'Ruthie Way',
#  'Mansfield Street',
#  'Marge Way',
#  'La Presa Avenue',
#  'Joris Way',
#  'Central Avenue',
#  'Farrington Drive',
#  'Vista Way',
#  'Santa Cruz Avenue',
#  'Bermuda Circle',
#  'Ridgecrest Drive',
#  'Jefferson Avenue',
#  'Duval Street',
#  'Rue Fontainbleau',
#  'Prince Charming Lane',
#  'Wooden Valley Street',
#  'Palm Avenue',
#  'Equitation Lane',
#  'Louisiana Street',
#  'Spear Street',
#  'Delaware Street',
#  'Saunders Court',
#  'Point Loma Avenue',
#  'Pentuckett Avenue',
#  'Camino de la Reina',
#  'Armstrong Street',
#  'Miracle Waters Court',
#  'Altamirano Way',
#  'Barstow Street',
#  'Hansel Drive',
#  'Clavelita Street',
#  'Nile Street',
#  'Showroom Place',
#  'Governor Drive',
#  'Governor Drive',
#  'West Fir Street',
#  '5th Avenue',
#  'University Avenue',
#  'San Diego Avenue',
#  'Camino del Rio North',
#  'La Mesa Boulevard',
#  '6th Avenue',
#  'Alvarado Road',
#  'Alvarado Road',
#  'Alvarado Road',
#  'Broadway',
#  'Caminito Alvarez',
#  '4th Avenue',
#  'El Cajon Boulevard',
#  'Convoy Street',
#  'North Harbor Drive',
#  'Gilman Drive',
#  'Avocado School Rd',
#  '3020 Childrens Way 03 Mi S Of I-805 / Kearny Villa Ic',
#  'Erlanger Street',
#  'Erlanger Street',
#  'Erlanger Street',
#  'Erlanger Street',
#  '1st Avenue',
#  '5th Street',
#  'Balboa Avenue',
#  'Regents Road',
#  'Regents Road',
#  'Chicago St',
#  'West B Street',
#  'Adobe Falls Road',
#  'Baltimore Street',
#  'Froude Street',
#  'Birch Road',
#  'Alta Road',
#  'Fletcher Parkway']

# %% [markdown]
# # Getting users and count

# %%
# Getting users and count

def get_user(element):
    return element.get('user')


def process_users_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if element.get('user'):
            users.add(get_user(element))
        element.clear()    
    return users


with open(OSM_FILE,'rb') as f:
    users = process_users_map(OSM_FILE)

print len(users)
#pprint.pprint(users)
f.close()
# Out:
# 1006

# %% [markdown]
# # Problem encountered**  - 1

# %% [markdown]
# 1) Street address abbreviation - The main problem we encountered in this dataset come from the street name abbreviation inconsistency. In this following code, we build the regex matching the last element in the string, where usually the street type is based. Then we come up with a list of mapping that need not to be cleaned. See Auditing Street Names.
#
# audit_street_type function search the input string for the regex. If there is a match and it is not within the "expected" list, add the match as a key and add the string to the set.
#
# is_street_name function looks at the attribute k if k="addre:street"
#
# audit function will return the list that match previous two functions. After that, we can do a pretty print the output of the audit. With the list of all the abbreviated street types we can understand and fill-up our "mapping" dictionary as a preparation to convert these street name into proper form.
#
# function update_name is the last step of the process, which take the old street name and update them with a better street name.

# %% [markdown]
# # Auditing Street Names

# %%
# Auditing Street Names

'''
We create a regex for the street names and store it in street_type_re. 
Furthermore we create a default dictionary that will include sets of different street names.
Then, we will audit the datafile and look for street names that have an ending that is different to
the values in the expected list.

'''



street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons","Freeway","Circle","Strand","Sterling","Way","Highway",
            "Terrace","South","East","West","North"]

# THIS VARIABLE CONTAINS THE CORRECTIONS
mapping = {
            " St ": " Street ",
            " St.": " Street ",
            " Rd.": " Road ",
            " Rd ": " Road ",
            " Rd": " Road ",
            " Ave ": " Avenue ", 
            " Ave.": " Avenue ",
            " Av ": " Avenue ", 
            " Dr ": " Drive ",
            " Dr.": " Drive",
            " Blvd ": " Boulevard ",
            " Blvd": " Boulevard",
            " Blvd.": " Boulevard",
            " Ct ": " Centre ",
            " Ctr": " Centre",
            " Pl ": " Place ",
            " Ln ": " Lane ",
            " Cir ": " Circle ",
            " Wy": " Way ",
            " S ": " South ",
            " E ": " East ",
            " W ": " West ",
            " N ": "North"
}

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(filename):
    f = open(filename, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(filename, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
            elem.clear()        
    f.close()
    return street_types


def update_name(name, mapping):
    for key,value in mapping.iteritems():
        if key in name:
            return name.replace(key,value)
    return name        
'''
Using the SAMPLE_FILE as an input to audit the street name
'''


st_types = audit(SAMPLE_FILE)

#pprint.pprint(dict(st_types))
for st_type, ways in st_types.iteritems():
    for name in ways:
        better_name = update_name(name, mapping)
        print name, "=>", better_name
# Out:
# Corte Playa Cartagena => Corte Playa Cartagena
# Port Dunbar => Port Dunbar
# Plaza Miraleste => Plaza Miraleste
# Corte Playa Pacifica => Corte Playa Pacifica
# Avenida Circo => Avenida Circo
# Camino Entrada => Camino Entrada
# Caminito Quintero => Caminito Quintero
# Avenida Benjamin => Avenida Benjamin
# Calle Santiago => Calle Santiago
# Calle de la Plata => Calle de la Plata
# Camino de Las Palmas => Camino de Las Palmas
# Caminito Marcial => Caminito Marcial
# Emerald Cove => Emerald Cove
# Via Bartolo => Via Bartolo
# Caminito Amparo => Caminito Amparo
# Caminito Joven => Caminito Joven
# Via Palma => Via Palma
# Paseo Ladera => Paseo Ladera
# Plaza Palo Alto => Plaza Palo Alto
# Rue Michelle => Rue Michelle
# Camino Elevado => Camino Elevado
# Caminito Pacheco => Caminito Pacheco
# Plaza del Cid => Plaza del Cid
# Rue Cheaumont => Rue Cheaumont
# Rue Michael => Rue Michael
# Casa Alta => Casa Alta
# Plaza Toluca => Plaza Toluca
# El Paseo Grande => El Paseo Grande
# Caminito Agrado => Caminito Agrado
# Caminito Halago => Caminito Halago
# Camino Largo => Camino Largo
# Calle Corta => Calle Corta
# Vista de la Bahia => Vista de la Bahia
# Camino Calabazo => Camino Calabazo
# Caminito DeGrazia => Caminito DeGrazia
# Via del Mesonero => Via del Mesonero
# Corte Melano => Corte Melano
# Caminito Perico => Caminito Perico
# Calle Catarina => Calle Catarina
# Vista Santa Catarina => Vista Santa Catarina
# Caminito Fuente => Caminito Fuente
# Broadway => Broadway
# West Broadway => West Broadway
# Caminito Recodo => Caminito Recodo
# Camino del Rey => Camino del Rey
# Via Barranca => Via Barranca
# Via Granero => Via Granero
# Via Trieste => Via Trieste
# Corte Playa Madera => Corte Playa Madera
# Calle Dellago => Calle Dellago
# Vista del Sur => Vista del Sur
# Lomo del Sur => Lomo del Sur
# Avenida de la Playa => Avenida de la Playa
# Via Encantadoras => Via Encantadoras
# Caminito Andreta => Caminito Andreta
# Calle Entre => Calle Entre
# Corte Playa Palmera => Corte Playa Palmera
# Calle Vaquero => Calle Vaquero
# Caminito Pintoresco => Caminito Pintoresco
# Caminito Mira => Caminito Mira
# Via Ladeta => Via Ladeta
# Via Tapia => Via Tapia
# Calle Vera Cruz => Calle Vera Cruz
# Plaza Cambria => Plaza Cambria
# Port Trinity => Port Trinity
# Catspaw Cape => Catspaw Cape
# Via Francis => Via Francis
# Santa Angela => Santa Angela
# Calle Tortuosa => Calle Tortuosa
# Caminito Munoz => Caminito Munoz
# Avenida Antonio => Avenida Antonio
# Via Nina => Via Nina
# Caminito Monrovia => Caminito Monrovia
# Corte Playa Barcelona => Corte Playa Barcelona
# Caminito Juanico => Caminito Juanico
# Via Suspiro => Via Suspiro
# Caminito Borde => Caminito Borde
# Caliente Loop => Caliente Loop
# Burga Loop => Burga Loop
# Eastridge Loop => Eastridge Loop
# Bayona Loop => Bayona Loop
# Sheep Ranch Loop => Sheep Ranch Loop
# Camino del Este => Camino del Este
# Corte Condesa => Corte Condesa
# Corte Mirador => Corte Mirador
# Calle Serena => Calle Serena
# Mercury Point => Mercury Point
# Sunset Crossing Point => Sunset Crossing Point
# Emerald Cliff Point => Emerald Cliff Point
# Caminito Cassis => Caminito Cassis
# Caminito Pudregal => Caminito Pudregal
# Paseo Los Castillos => Paseo Los Castillos
# Via Palabra => Via Palabra
# Via Costina => Via Costina
# Rue Le Blanc => Rue Le Blanc
# Corte San Simeon => Corte San Simeon
# Paseo Castanada => Paseo Castanada
# Caminito Dehesa => Caminito Dehesa
# Caminito Alvarez => Caminito Alvarez
# Via Escalante => Via Escalante
# Calle Miramar => Calle Miramar
# Vista Santa Rita => Vista Santa Rita
# Via Las Tonadas => Via Las Tonadas
# Camino Tranquilo => Camino Tranquilo
# Caminito Partida => Caminito Partida
# Calle Trepadora => Calle Trepadora
# Avenida Costa Norte => Avenida Costa Norte
# Avenida Playa Cancun => Avenida Playa Cancun
# Avenida Abajo => Avenida Abajo
# Calle Aguadulce => Calle Aguadulce
# Via Anita => Via Anita
# Calle Empinada => Calle Empinada
# Pinewood View => Pinewood View
# Paseo Primavera => Paseo Primavera
# El Nopal => El Nopal
# Avenida Wilfredo => Avenida Wilfredo
# Caminito Salado => Caminito Salado
# Camino Playa Malaga => Camino Playa Malaga
# Chicago St => Chicago St
# Circulo Coronado => Circulo Coronado
# Vista Santa Margarit => Vista Santa Margarit
# Rue Cannes => Rue Cannes
# Port Chelsea => Port Chelsea
# Via Playa de Cortes => Via Playa de Cortes
# Via Diana => Via Diana
# Caminito Mojado => Caminito Mojado
# Via Papeete => Via Papeete
# Aztec Walk => Aztec Walk
# Bayside Walk => Bayside Walk
# Ocean Front Walk => Ocean Front Walk
# Via del Bardo => Via del Bardo
# Camino de la Reina => Camino de la Reina
# Via Carancho => Via Carancho
# Villa Bonita => Villa Bonita
# Camino la Paz => Camino la Paz
# Caminito de la Escena => Caminito de la Escena
# Plaza Amistad => Plaza Amistad
# Via de la Bandola => Via de la Bandola
# Paseo del Cerro => Paseo del Cerro
# Calle Chanate => Calle Chanate
# Plaza Mar => Plaza Mar
# Caminito Tamborrel => Caminito Tamborrel
# Avenida Fiesta => Avenida Fiesta
# Calle Naranja => Calle Naranja
# Caminito Estrella => Caminito Estrella
# Paseo Dorado => Paseo Dorado
# Port Renwick => Port Renwick
# Corte Pozos => Corte Pozos
# Vista Coyote => Vista Coyote
# Rue Fontainbleau => Rue Fontainbleau
# Via Cinta => Via Cinta
# Camino de la Costa => Camino de la Costa
# Avenida Chamnez => Avenida Chamnez
# Plaza Cuernavaca => Plaza Cuernavaca
# Avenida Cherylita => Avenida Cherylita
# Avenida Colino => Avenida Colino
# Caminito Cumbres => Caminito Cumbres
# Caminito Garcia => Caminito Garcia
# Via Carlotta => Via Carlotta
# Plaza Miroda => Plaza Miroda
# Rue Saint Jacques => Rue Saint Jacques
# Via Alfalfa => Via Alfalfa
# Calle Mesita => Calle Mesita
# Avenida del Mexico => Avenida del Mexico
# Avenida Cresta => Avenida Cresta
# Trinidad Bend => Trinidad Bend
# Bridgetown Bend => Bridgetown Bend
# Port Cardiff => Port Cardiff
# Park Row => Park Row
# Carriagedale Row => Carriagedale Row
# Encino Row => Encino Row
# Caminito Cachorro => Caminito Cachorro

# %% [markdown]
# In the above audit of the street name, SAMPLE_FILE was used and there were no potential errors produced.However, errors were produced with bigger SAMPLE_FILE and original OSM file which were then corrected.

# %% [markdown]
# # Improving Street Names - Cleaning up and Fixing the Street Names during shape_element function

# %%
# Cleaning up and Fixing the Street Names

'''
Now we are going to do some data cleaning to enhance the data quality of the street names.
We have identified sets of street name endings that have been expected. Through a a mapping dictionary we 
indicate the desired changes. We do this for the street name endings (mapping).
'''




street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons","Freeway","Circle","Strand","Sterling","Way","Highway",
            "Terrace","South","East","West","North"]

# UPDATE THIS VARIABLE
mapping = {
            " St ": " Street ",
            " St.": " Street ",
            " Rd.": " Road ",
            " Rd ": " Road ",
            " Rd": " Road ",
            " Ave ": " Avenue ", 
            " Ave.": " Avenue ",
            " Av ": " Avenue ", 
            " Dr ": " Drive ",
            " Dr.": " Drive",
            " Blvd ": " Boulevard ",
            " Blvd": " Boulevard",
            " Blvd.": " Boulevard",
            " Ct ": " Centre ",
            " Ctr": " Centre",
            " Pl ": " Place ",
            " Ln ": " Lane ",
            " Cir ": " Circle ",
            " Wy": " Way ",
            " S ": " South ",
            " E ": " East ",
            " W ": " West ",
            " N ": "North"
}


'''
The update name function implements the change. If a street name has the defined string which is defined in the mapping
dictionary, then the change is made as defined.
'''

'''
Below 2 functions would be used during shape_element function execution to formatt the street name

'''

def update_street_name(name, mapping):
    for key,value in mapping.iteritems():
        if key in name:
            return name.replace(key,value)
    return name        

def audit_street_name_tag(element): 
    street_name=element.get('v')
    m = street_type_re.search(street_name)
    if m:
        better_street_name=update_street_name(street_name,mapping)
        return better_street_name
    return street_name

# %% [markdown]
# # Problem encountered**  - 2

# %% [markdown]
# 2) Postcodes - We can re-use part of the code in street abbreviation problem and briefly modify it to use it here. Although most of the postcode is correct, there're still a lot of  postcode with incorrect 5 digit formats. Like some postcodes have "-" followed by another string of numbers, some postcodes have "CA " attached infront of them, some postcodes are more than 5 digits. All of these cases have been dealt to produce a clean postcode.
#
# The output of the clean postcode is summarised below.

# %% [markdown]
# # Auditing Postal Codes

# %%
# Auditing Postal Codes

'''
In this Section we are going to audit postal codes to check for potential errors. This is a very similar process compared to
to our cleaning street name strategy

'''

zip_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

zip_types = defaultdict(set)

expected_zip = {}

def audit_zip_codes(zip_types, zip_name, regex, expected_zip):
    m = regex.search(zip_name)
    if m:
        zip_type = m.group()
        if zip_type not in expected_zip:
             zip_types[zip_type].add(zip_name)

def is_zip_name(elem):
    return (elem.attrib['k'] == "addr:postcode")


def audit(filename, regex):
    for event, elem in ET.iterparse(filename, events=("start",)):
        if elem.tag == "way" or elem.tag == "node":
            for tag in elem.iter("tag"):
                if is_zip_name(tag):
                    audit_zip_codes(zip_types, tag.attrib['v'], regex, expected_zip)
    pprint.pprint(dict(zip_types))


'''
Using the SAMPLE_FILE as an input to audit the postcodes
'''   
    
audit(SAMPLE_FILE, zip_type_re)


for zip_type, ways in zip_types.iteritems(): 
        for name in ways:
            if "-" in name:
                name = name.split("-")[0].strip()
            if "CA " in name:
                name = name.split("CA ")[1].strip('CA ')
            elif len(str(name))>5:
                name=name[0:5]
            elif name.isdigit()==False:
                print 'OK'
            print name
# Out:
# {'91902': set(['91902']),
#  '91910': set(['91910']),
#  '91911': set(['91911']),
#  '91913': set(['91913']),
#  '91914': set(['91914']),
#  '91915': set(['91915']),
#  '91932': set(['91932']),
#  '91941': set(['91941']),
#  '91942': set(['91942']),
#  '91945': set(['91945']),
#  '91950': set(['91950']),
#  '91977': set(['91977']),
#  '91978': set(['91978']),
#  '92019': set(['92019']),
#  '92020': set(['92020']),
#  '92021': set(['92021']),
#  '92037': set(['92037']),
#  '92040': set(['92040']),
#  '92071': set(['92071']),
#  '92101': set(['92101']),
#  '92102': set(['92102']),
#  '92103': set(['92103']),
#  '92104': set(['92104']),
#  '92105': set(['92105']),
#  '92106': set(['92106']),
#  '92107': set(['92107']),
#  '92108': set(['92108']),
#  '92109': set(['92109']),
#  '92110': set(['92110']),
#  '92111': set(['92111']),
#  '92113': set(['92113']),
#  '92114': set(['92114']),
#  '92115': set(['92115']),
#  '92116': set(['92116']),
#  '92117': set(['92117']),
#  '92118': set(['92118']),
#  '92119': set(['92119']),
#  '92120': set(['92120']),
#  '92121': set(['92121']),
#  '92122': set(['92122']),
#  '92123': set(['92123']),
#  '92124': set(['92124']),
#  '92126': set(['92126']),
#  '92131': set(['92131']),
#  '92139': set(['92139']),
#  '92154': set(['92154']),
#  '92173': set(['92173']),
#  '92182': set(['92182'])}
# 91945
# 91942
# 91941
# 91902
# 92121
# 92120
# 92123
# 92122
# 92124
# 92071
# 92126
# 92107
# 92106
# 92105
# 92104
# 92103
# 92102
# 92101
# 92037
# 91932
# 92019
# 92182
# 92154
# 91977
# 91950
# 91911
# 91910
# 91913
# 91978
# 91915
# 91914
# 92021
# 92118
# 92119
# 92131
# 92109
# 92110
# 92111
# 92139
# 92114
# 92115
# 92116
# 92117
# 92108
# 92040
# 92113
# 92020
# 92173

# %% [markdown]
# In the above audit of the postcode, SAMPLE_FILE was used and there were no potential errors produced.However, errors were produced with bigger SAMPLE_FILE and original OSM file which were then corrected.

# %% [markdown]
# # Cleaning and Fixing Postal Codes during the shape_element function

# %%
'''
We want to have all postal codes in the standard 5 digit display. This means we have to change the postal codes 
that have more than 5 digits, the ones that beginn with "CA" and any other ones that differ from the the plain 5
digit display.
'''


'''
Below 2 functions would be used during shape_element function execution to formatt the postcode
'''


def update_postcode(name): 
    if "-" in name:
        name = name.split("-")[0].strip()
    elif "CA" in name:
        name = name.split("CA ")[1].strip('CA ')
    elif len(str(name))>5:
        name=name[0:5]
    elif name.isdigit()==False:
         name=00000
    return name



def audit_postcode_tag(element,regex=re.compile(r'\b\S+\.?$', re.IGNORECASE)):
    post_code=element.get('v')
    m = regex.search(post_code)
    if m:
        better_postcode=update_postcode(post_code)
        return better_postcode
    return post_code

# %% [markdown]
# # Preparing for Database - SQL

# %%
 '''
 Note: The schema is stored in a .py file in order to take advantage of the
 int() and float() type coercion functions. Otherwise it could easily stored as
 as JSON or another serialized format.
 '''

schema = {
    'node': {
        'type': 'dict',
        'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'lat': {'required': True, 'type': 'float', 'coerce': float},
            'lon': {'required': True, 'type': 'float', 'coerce': float},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
        }
    },
    'node_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    },
    'way': {
        'type': 'dict',
        'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
        }
    },
    'way_nodes': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'node_id': {'required': True, 'type': 'integer', 'coerce': int},
                'position': {'required': True, 'type': 'integer', 'coerce': int}
            }
        }
    },
    'way_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    }
}

# %% [markdown]
# # Defining CSV Files and their respective columns

# %%
NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


SCHEMA = schema


NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

# %% [markdown]
# # Shaping up the element

# %%
 """Clean and shape node or way XML element to Python dict"""

def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    
    
    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = [] # Handle secondary tags the same way for both node and way elements
             

   

    if element.tag=='node':
        for field in node_attr_fields:
            node_attribs[field]=element.get(field)
                 
        if element.find('tag') is None:
            pass
#           print 'No Tags'
           
        elif element.find('tag') is not None:
            tag_attrib={}
            node_tag_fields=NODE_TAGS_FIELDS
            for tag in element.iter('tag'):
                if PROBLEMCHARS.search(tag.attrib['k']):
                    pass
                elif LOWER_COLON.search(tag.attrib['k']):
                    tag_attrib[node_tag_fields[0]]=element.get('id')
                    tag_attrib[node_tag_fields[1]]=tag.get('k')[(tag.get('k').find(':')+1):]
                    if tag.attrib['k']== "addr:street":
                        tag_attrib[node_tag_fields[2]]=audit_street_name_tag(tag)
                    elif tag.attrib['k']== "addr:postcode":
                        tag_attrib[node_tag_fields[2]]=audit_postcode_tag(tag)       
                    else:
                        tag_attrib[node_tag_fields[2]]=tag.get('v')
                    tag_attrib[node_tag_fields[3]]=tag.get('k').split(':')[0]
                    tags.append(tag_attrib.copy())
                
                else:
                    tag_attrib[node_tag_fields[0]]=element.get('id')
                    tag_attrib[node_tag_fields[1]]=tag.get('k')
                    if tag.attrib['k']== "addr:street":
                        tag_attrib[node_tag_fields[2]]=audit_street_name_tag(tag)
                    elif tag.attrib['k']== "addr:postcode":
                        tag_attrib[node_tag_fields[2]]=audit_postcode_tag(tag)    
                    else:    
                        tag_attrib[node_tag_fields[2]]=tag.get('v')
                    tag_attrib[node_tag_fields[3]]=default_tag_type
                    tags.append(tag_attrib.copy())
            
#        pprint.pprint( {'node':node_attribs,'node_tags':tags})  
        
                
    elif element.tag=='way':
        for field in way_attr_fields:
            way_attribs[field]=element.get(field)
    
        way_node_attrib={}
        way_node_fields=WAY_NODES_FIELDS
        for nd in element.findall('nd'):
            way_node_attrib[way_node_fields[0]]=element.get('id')
            way_node_attrib[way_node_fields[1]]=nd.get('ref')
            way_node_attrib[way_node_fields[2]]=element.findall('nd').index(nd)
            way_nodes.append(way_node_attrib.copy())
#       pprint.pprint({'way':way_attribs,'way_nodes':way_nodes})
        
        
        
        
        if element.find('tag') is None:
            pass
#           print 'No Tags'
           
        elif element.find('tag') is not None:
            way_tag_attrib={}
            way_tag_fields=WAY_TAGS_FIELDS
            for tag in element.iter('tag'):
                if PROBLEMCHARS.search(tag.attrib['k']):
                    pass
                elif LOWER_COLON.search(tag.attrib['k']):
                    way_tag_attrib[way_tag_fields[0]]=element.get('id')
                    way_tag_attrib[way_tag_fields[1]]=tag.get('k')[(tag.get('k').find(':')+1):]
                    if tag.attrib['k']== "addr:street":
                        way_tag_attrib[way_tag_fields[2]]=audit_street_name_tag(tag)
                    elif tag.attrib['k']== "addr:postcode":
                        way_tag_attrib[way_tag_fields[2]]=audit_postcode_tag(tag)    
                    else:
                        way_tag_attrib[way_tag_fields[2]]=tag.get('v')
                    way_tag_attrib[way_tag_fields[3]]=tag.get('k').split(':')[0]
                    tags.append(way_tag_attrib.copy())
                    
                else:
                    way_tag_attrib[way_tag_fields[0]]=element.get('id')
                    way_tag_attrib[way_tag_fields[1]]=tag.get('k')
                    if tag.attrib['k']== "addr:street":
                        way_tag_attrib[way_tag_fields[2]]=audit_street_name_tag(tag) 
                    elif tag.attrib['k']== "addr:postcode":
                        way_tag_attrib[way_tag_fields[2]]=audit_postcode_tag(tag)    
                    else:   
                        way_tag_attrib[way_tag_fields[2]]=tag.get('v')
                    way_tag_attrib[way_tag_fields[3]]=default_tag_type
                    tags.append(way_tag_attrib.copy())
#        pprint.pprint({'way':way_attribs,'way_tags':tags})
#        pprint.pprint({'way':way_attribs,'way_nodes':way_nodes,'way_tags':tags})
        
    

    
    if element.tag == 'node':
        return {'node': node_attribs, 'node_tags': tags}
    elif element.tag == 'way':
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}

# %% [markdown]
# # Helper function - Validating the element

# %%
def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))

# %% [markdown]
# # Helper function - UnicodeDictWriter

# %%
class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)

# %% [markdown]
# # Writing CSV Files

# %%
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
        codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])

# %% [markdown]
# # Loading the data into CSV file from OSM File

# %%
process_map(OSM_FILE, validate=True)

# %% [markdown]
# # Creating and Connecting to SQL database

# %%
db = sqlite3.connect("san-diego_california")  # Connect to the database
                                              # "san-diego_california" is the name of the sqlite database file
                                
c = db.cursor() # Get a cursor object

# %% [markdown]
# # Creating nodes table

# %%
# creating nodes table in database san-diego_california and inserting values into table nodes

query="DROP TABLE IF EXISTS nodes;" # Dropping the table if it already exists
c.execute(query);
db.commit()
query = "CREATE TABLE nodes (id INTEGER PRIMARY KEY NOT NULL,lat REAL,lon REAL,user TEXT,uid INTEGER,version INTEGER,changeset INTEGER,timestamp TEXT);"
c.execute(query)
db.commit()

# Read in the csv file as a dictionary, format the data as a list of tuples:

with open('nodes.csv','rb') as f: 
    dr = csv.DictReader(f)
    to_db = [(i['id'].decode("utf-8"),i['lat'].decode("utf-8"),i['lon'].decode("utf-8"),i['user'].decode("utf-8"),i['uid'].decode("utf-8"),i['version'].decode("utf-8"),i['changeset'].decode("utf-8"),i['timestamp'].decode("utf-8")) for i in dr]
    
# insert the formatted data

c.executemany("INSERT INTO nodes (id, lat, lon, user, uid, version, changeset, timestamp) VALUES (?,?,?,?,?,?,?,?);", to_db)
db.commit()
f.close()

# %% [markdown]
# # Creating nodes_tags table

# %%
# creating nodes_tags table in database san-diego_california and inserting values into table nodes_tags

query="DROP TABLE IF EXISTS nodes_tags;"  # Dropping the table if it already exists
c.execute(query);
db.commit()
query = "CREATE TABLE nodes_tags (id INTEGER,key TEXT,value TEXT,type TEXT,FOREIGN KEY (id) REFERENCES nodes(id));"
c.execute(query)
db.commit()

# Read in the csv file as a dictionary, format the data as a list of tuples:

with open('nodes_tags.csv','rb') as f: 
    dr = csv.DictReader(f)
    to_db = [(i['id'].decode("utf-8"),i['key'].decode("utf-8"),i['value'].decode("utf-8"),i['type'].decode("utf-8")) for i in dr]

# insert the formatted data

c.executemany("INSERT INTO nodes_tags (id, key, value, type) VALUES (?,?,?,?);", to_db)
db.commit()
f.close()

# %% [markdown]
# # Creating ways table

# %%
# creating ways table in database san-diego_california and inserting values into table ways

query="DROP TABLE IF EXISTS ways;"   # Dropping the table if it already exists
c.execute(query);
db.commit()
query = "CREATE TABLE ways(id INTEGER PRIMARY KEY NOT NULL,user TEXT,uid INTEGER,version TEXT,changeset INTEGER,timestamp TEXT);"
c.execute(query)
db.commit()

# Read in the csv file as a dictionary, format the data as a list of tuples:

with open('ways.csv','rb') as f: 
    dr = csv.DictReader(f)
    to_db = [(i['id'].decode("utf-8"),i['user'].decode("utf-8"),i['uid'].decode("utf-8"),i['version'].decode("utf-8"),i['changeset'].decode("utf-8"),i['timestamp'].decode("utf-8")) for i in dr]

# insert the formatted data        
    
c.executemany("INSERT INTO ways (id, user, uid, version, changeset, timestamp) VALUES (?,?,?,?,?,?);", to_db)
db.commit()
f.close()

# %% [markdown]
# # Creating ways_nodes table

# %%
# creating ways_nodes table in database san-diego_california and inserting values into table ways_nodes

query="DROP TABLE IF EXISTS ways_nodes;"  # Dropping the table if it already exists
c.execute(query);
db.commit()
query = "CREATE TABLE ways_nodes (id INTEGER NOT NULL,node_id INTEGER NOT NULL,position INTEGER NOT NULL,FOREIGN KEY (id) REFERENCES ways(id),FOREIGN KEY (node_id) REFERENCES nodes(id));"
c.execute(query)
db.commit()

# Read in the csv file as a dictionary, format the data as a list of tuples:

with open('ways_nodes.csv','rb') as f: 
    dr = csv.DictReader(f)
    to_db = [(i['id'].decode("utf-8"),i['node_id'].decode("utf-8"),i['position'].decode("utf-8")) for i in dr]

    
# insert the formatted data 
    
c.executemany("INSERT INTO ways_nodes (id, node_id, position) VALUES (?,?,?);", to_db)
db.commit()
f.close()

# %% [markdown]
# # Creating ways_tags table

# %%
# creating ways_tags table in database san-diego_california and inserting values into table ways_nodes

query="DROP TABLE IF EXISTS ways_tags;"   # Dropping the table if it already exists
c.execute(query);
db.commit()
query = "CREATE TABLE ways_tags (id INTEGER NOT NULL,key TEXT NOT NULL,value TEXT NOT NULL,type TEXT,FOREIGN KEY (id) REFERENCES ways(id));"
c.execute(query)
db.commit()


# Read in the csv file as a dictionary, format the data as a list of tuples:

with open('ways_tags.csv','rb') as f: 
    dr = csv.DictReader(f)
    to_db = [(i['id'].decode("utf-8"),i['key'].decode("utf-8"),i['value'].decode("utf-8"),i['type'].decode("utf-8")) for i in dr]

# insert the formatted data 

c.executemany("INSERT INTO ways_tags (id, key, value, type) VALUES (?,?,?,?);", to_db)
db.commit()
f.close()

# %% [markdown]
# # Overview of The Data

# %% [markdown]
# This section contains basic statistics about the San Diego OpenStreetMap dataset and the SQL queries used to gather them.

# %% [markdown]
# # File sizes -

# %% [markdown]
# san-diego_california.osm  290 MB
# san-diego_california.db   195 MB
# nodes.csv                 79.2 MB
# nodes_tags.csv            83.0 MB
# ways.csv                  4.98 MB
# ways_nodes.csv            18.3 MB
# ways_tags.csv             19.2 MB

# %% [markdown]
# # Number of unique users

# %%
query = "SELECT COUNT(DISTINCT(e.uid))FROM (SELECT uid FROM Nodes UNION ALL SELECT uid FROM Ways) as e;"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)
# Out:
# [(993,)]

# %% [markdown]
# Number of Unique Users is 993.

# %% [markdown]
# # Number of nodes

# %%
query = "SELECT count(DISTINCT(id)) FROM nodes;"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)
# Out:
# [(1017755,)]

# %% [markdown]
# Number of Nodes is  1017755.

# %% [markdown]
# # Number of Ways

# %%
query = "SELECT count(DISTINCT(id)) FROM ways;"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)
# Out:
# [(88531,)]

# %% [markdown]
# Number of ways are 88531.

# %% [markdown]
# # Number of chosen type of nodes

# %%
# number of chosen type of nodes

query = "SELECT type , count(*) as num  FROM nodes_tags group by type order by num desc;"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)
# Out:
# [(u'addr', 1643780),
#  (u'regular', 395218),
#  (u'is_in', 45587),
#  (u'gnis', 7111),
#  (u'seamark', 1790),
#  (u'source', 176),
#  (u'wetap', 113),
#  (u'beacon', 99),
#  (u'payment', 64),
#  (u'recycling', 53),
#  (u'diet', 50),
#  (u'name', 38),
#  (u'contact', 29),
#  (u'prosper', 28),
#  (u'fire_hydrant', 24),
#  (u'service', 21),
#  (u'caltrans', 20),
#  (u'tiger', 20),
#  (u'maxspeed', 16),
#  (u'ref', 16),
#  (u'alt_name', 9),
#  (u'census', 9),
#  (u'exit_to', 8),
#  (u'railway', 8),
#  (u'tower', 8),
#  (u'building', 7),
#  (u'healthcare', 5),
#  (u'crossing', 4),
#  (u'charging_station', 3),
#  (u'disused', 3),
#  (u'internet_access', 3),
#  (u'location', 3),
#  (u'sanitary_dump_station', 3),
#  (u'socket', 3),
#  (u'buoy', 2),
#  (u'fuel', 2),
#  (u'monitoring', 2),
#  (u'note', 2),
#  (u'place', 2),
#  (u'social_facility', 2),
#  (u'toilets', 2),
#  (u'topmark', 2),
#  (u'traffic_signals', 2),
#  (u'wheelchair', 2),
#  (u'description', 1),
#  (u'golf', 1),
#  (u'heritage', 1),
#  (u'swing_gate', 1)]

# %%
# number of chosen type of nodes, like cafes, shops etc.

query = "SELECT value, count(*) FROM (select key,value from nodes_tags UNION ALL select key,value from ways_tags) as e where value like '%cafe%';"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)


print '\n'

query = "SELECT value, count(*)  FROM (select key,value from nodes_tags UNION ALL select key,value from ways_tags) as e where value like 'shop%';"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)
# Out:
# [(u'cafe', 287)]
#
#
# [(u'shop', 11)]

# %% [markdown]
# # Top 10 contributing users

# %%
#Top 10 contributing users

query = "select e.user, count(*) as num from (select user from nodes UNION ALL select user from ways) as e group by user order by num desc limit 10;"
c.execute(query)
rows=c.fetchall()
print 'Top 10 contributing users and their contribution:\n'
pprint.pprint(rows)



#Total users
print '\n'
print 'Total appearances of the users:\n'
query = "select count(e.user) from (select user from nodes UNION ALL select user from ways) as e;"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)
# Out:
# Top 10 contributing users and their contribution:
#
# [(u'n76', 335145),
#  (u'Adam Geitgey', 162980),
#  (u'Sat', 128338),
#  (u'woodpeck_fixbot', 91625),
#  (u'Zian Choy', 16886),
#  (u'Brian@Brea', 15927),
#  (u'TieFaith', 12997),
#  (u'stevea', 12641),
#  (u'evil saltine', 12147),
#  (u'javbw', 10606)]
#
#
# Total appearances of the users:
#
# [(1106286,)]

# %% [markdown]
# So, from the above 2 queries, it is observed that user 'n76' has appeared 335145 times from 1106286 which consists of about 30.29 % of the total counts.

# %% [markdown]
# # Top 20 keys in tags with respect to count size

# %%
#Top 20 keys in tags with respect to count size

query = "select e.key , count(*) as num from (select key from nodes_tags UNION ALL select key from ways_tags) as e group by e.key order by num desc limit 20;"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)
# Out:
# [(u'source', 386765),
#  (u'country', 350731),
#  (u'street', 344486),
#  (u'housenumber', 344298),
#  (u'city', 314944),
#  (u'postcode', 307985),
#  (u'highway', 67441),
#  (u'name', 41278),
#  (u'county', 31327),
#  (u'cfcc', 31135),
#  (u'name_base', 27174),
#  (u'name_type', 24607),
#  (u'building', 23242),
#  (u'zip_left', 22980),
#  (u'reviewed', 22796),
#  (u'zip_right', 22403),
#  (u'tlid', 15593),
#  (u'oneway', 14123),
#  (u'separated', 14044),
#  (u'building_type', 13176)]

# %% [markdown]
# From the above query, it is observed that tags with K value 'Source' occured maximum time.

# %% [markdown]
# # Top 20 value in tags with respect to count size

# %%
#Top 20 value in tags with respect to count size

query = "select e.value, count(e.value) as num from (select value from nodes_tags UNION ALL select value from ways_tags) as e group by value order by num desc limit 20;"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)
# Out:
# [(u'US', 350708),
#  (u'SanGIS Addresses Public Domain (http://www.sangis.org/)', 342634),
#  (u'San Diego', 187987),
#  (u'no', 41193),
#  (u'yes', 38538),
#  (u'San Diego, CA', 31345),
#  (u'A41', 25902),
#  (u'Chula Vista', 24073),
#  (u'El Cajon', 19432),
#  (u'residential', 19166),
#  (u'La Mesa', 16561),
#  (u'92114', 16517),
#  (u'92117', 15953),
#  (u'tiger_import_dch_v0.6_20070809', 15602),
#  (u'91977', 14507),
#  (u'service', 14457),
#  (u'Spring Valley', 14372),
#  (u'92154', 14147),
#  (u'91941', 13491),
#  (u'CA', 13058)]

# %% [markdown]
# From the above query, it is observed that tags with v value 'US' occured maximum time.

# %% [markdown]
# # when was the 1st Contribution made and by whom

# %%
query = "select e.user, e.timestamp as num from (select user,timestamp from nodes UNION ALL select user,timestamp from ways) as e order by num limit 1;"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)
# Out:
# [(u'DaveHansenTiger', u'2007-09-10T17:51:45Z')]

# %% [markdown]
# 1st Contribution to San-diego OSM database was made by user 'DaveHansenTiger' at 17:56 hrs on 2007-09-10

# %% [markdown]
# # Top 20 Website Links

# %%
query = "select e.value, count(*) as num from (select value from nodes_tags UNION ALL select value from ways_tags) as e WHERE value LIKE '%www.%' group by e.value order by num desc limit 20;"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)
# Out:
# [(u'SanGIS Addresses Public Domain (http://www.sangis.org/)', 342634),
#  (u'SanGIS Footprints_Nonresidential_SD public domain (http://www.sangis.org/)',
#   12965),
#  (u'SanDag Public Transit (http://www.sandag.org/)', 2161),
#  (u'SanGIS Business Sites Public Domain (http://www.sangis.org/)', 667),
#  (u'Caltrans http://www.dot.ca.gov/hq/traffops/trucks/truckmap/', 537),
#  (u'SanGIS Freeways_SD public domain (http://www.sangis.org/)', 145),
#  (u'TIGER/Line\xae 2008 Place Shapefiles (http://www.census.gov/geo/www/tiger/)',
#   67),
#  (u'http://www.mcdonalds.com/', 55),
#  (u'http://www.southbayexpressway.com/about/faq.php#miscbicycles', 44),
#  (u'SanGIS Addresses Public Domain (http://www.sangis.org/);SanGIS Business Sites Public Domain (http://www.sangis.org/)',
#   37),
#  (u'Bing;SanDag Public Transit (http://www.sandag.org/)', 35),
#  (u'SanGIS Footprints_Military_Facility public domain (http://www.sangis.org/)',
#   29),
#  (u'http://www.dot.ca.gov/hq/tsip/gis/datalibrary/gisdatalibrary.html', 26),
#  (u'http://www.dot.ca.gov/dist11/departments/planning/pdfs/tcs/11_SR_11TCS.pdf',
#   16),
#  (u'http://www.sandiego.gov/stormwater/pdf/district3schedule.pdf', 16),
#  (u'Bing;SanGIS Addresses Public Domain (http://www.sangis.org/)', 12),
#  (u'SanGIS Business Sites Public Domain (http://www.sangis.org/);SanGIS Addresses Public Domain (http://www.sangis.org/)',
#   11),
#  (u'http://www.sangis.org/', 11),
#  (u'http://www.dot.ca.gov/hq/tsip/gis/datalibrary/gisdatalibrary.html, bing',
#   10),
#  (u'http://www.dot.ca.gov/dist11/facts/11_OtayEast.pdf', 9)]

# %% [markdown]
# # Popular Cuisines

# %%
query="select value,count(*) as num from (select key,value from nodes_tags UNION ALL select key,value from ways_tags) as e where e.key like '%cuisine%' group by value order by num desc limit 20;"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)
# Out:
# [(u'burger', 205),
#  (u'mexican', 128),
#  (u'sandwich', 97),
#  (u'pizza', 77),
#  (u'american', 42),
#  (u'coffee_shop', 41),
#  (u'chinese', 28),
#  (u'italian', 27),
#  (u'chicken', 23),
#  (u'japanese', 19),
#  (u'thai', 18),
#  (u'sushi', 16),
#  (u'ice_cream', 15),
#  (u'bagel', 12),
#  (u'indian', 11),
#  (u'regional', 10),
#  (u'greek', 8),
#  (u'steak_house', 6),
#  (u'vegan', 6),
#  (u'breakfast', 5)]

# %% [markdown]
# # List of keys where type is addr

# %%
query="select DISTINCT(key) from nodes_tags where type='addr';"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)
# Out:
# [(u'city',),
#  (u'street',),
#  (u'country',),
#  (u'housenumber',),
#  (u'state',),
#  (u'postcode',),
#  (u'unit',),
#  (u'housename',),
#  (u'full',),
#  (u'county',),
#  (u'door',),
#  (u'zipcode',),
#  (u'suite',)]

# %% [markdown]
# # Common ammenities

# %%
query="select value, count(*) as num from nodes_tags where key='amenity' group by value order by num desc limit 20;"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)
# Out:
# [(u'place_of_worship', 913),
#  (u'fast_food', 534),
#  (u'restaurant', 461),
#  (u'school', 299),
#  (u'bar', 269),
#  (u'cafe', 162),
#  (u'fuel', 106),
#  (u'bank', 81),
#  (u'bench', 71),
#  (u'drinking_water', 71),
#  (u'library', 65),
#  (u'toilets', 65),
#  (u'bicycle_parking', 64),
#  (u'post_office', 55),
#  (u'atm', 53),
#  (u'hospital', 51),
#  (u'fountain', 48),
#  (u'post_box', 47),
#  (u'shelter', 47),
#  (u'waste_basket', 42)]

# %% [markdown]
# # Religions

# %%
query="select value, count(*) as num from (select key,value from nodes_tags UNION ALL select key,value from ways_tags) as e  where key='religion' group by value order by num desc;"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)
# Out:
# [(u'christian', 874),
#  (u'jewish', 9),
#  (u'muslim', 7),
#  (u'buddhist', 5),
#  (u'hindu', 4),
#  (u'ascended_master_teachings', 1),
#  (u'bahai', 1),
#  (u'scientologist', 1),
#  (u'taoist', 1),
#  (u'unitarian', 1),
#  (u'unitarian_universalist', 1)]

# %% [markdown]
# # Dataset Improvement -

# %% [markdown]
# # Percentage of wheelchair accessible nodes

# %%
query="select count(*) from (select key,value from nodes_tags UNION ALL select key,value from ways_tags) as e  where key like '%wheelchair%';"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)
# Out:
# [(134,)]

# %% [markdown]
# # Number of nodes

# %%
query="select count(DISTINCT(id)) from  nodes_tags;"
c.execute(query)
rows=c.fetchall()

pprint.pprint(rows)
# Out:
# [(370105,)]

# %% [markdown]
# # Percentage of nodes with wheelchair accessibility information

# %% [markdown]
# 134/370105 = 3.620594155712568e-4 which is almost 0.
#
# Based on the above 2 queries, approximately 0.003% of the nodes in the dataset contain wheelchair accessibility information. That seems like a strikingly low number, even with a large amount of nodes.

# %% [markdown]
# # Ideas for additional improvements

# %% [markdown]
# One way to improve this wheelchair accessibility number is to leverage the public data provided by http://data.sandiego.gov/, http://www.sangis.org/download/), and similar resources.Wheelchair Accessibility information for hundreds of restaurants, cafes, tourist attractions, community centers, and other public spaces could be added to the dataset. Programmatically extracting the yes/no information and adding it to the OpenStreetMap dataset would likely be most efficient. We can also cross-reference/cross-validate missing data from other database like Google API as each node has a particular coordinate (lattitude & longtitude). It's also extremely important to attract more people to improving maps. Use of gamification can be another measure. It's reasonable to establish ranking system like on Kaggle or badge system like on Khan academy. It would increase the productivity and the missing information in the OSM data would be added.

# %% [markdown]
# # Anticipated problems in implementing the improvement

# %% [markdown]
# 1) One difficulty would be dealing with naming inconsistencies between different data sources and nodes already in the OpenStreetMap dataset, though this could be overcome with careful string handling and a human verifying inputted data.
#
# 2) Amount of effort to engineer all these processes and the cost of creating, auditing & maintaining these initiatives could be so overwhelm and may require a dedicated team responsible for all these projects.

# %% [markdown]
# # Conclusion

# %% [markdown]
# The San-Diego OpenStreetMap dataset is a quite large. When we audit the data, it was very clear that although there are minor error caused by human input, the dataset is fairly well-cleaned. Considering there're hundreds of contributors for this map, there are number of human errors in this dataset. I'd recommend a srtuctured input form so everyone can input the same data format to reduce this error or we can create a more robust script to clean the data on a regular basis.While it is clear that the data is not 100% clean, I believe it was sufficiently cleaned for the purposes of this project.A detailed investigation could also be done to identify which users created the features with incorrect or mismatched values in order to potentially identify additional documents for closer scrutiny or to predict what types of users are more prone to producing errors.This dataset shows the need for a standardized data schema, as well as the difficulty of having many different data sources and having information which needs to be constantly updated.
